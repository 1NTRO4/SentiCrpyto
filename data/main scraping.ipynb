# %% [markdown]
# Webscrapping for Cryptocurrency related news
# ### 2060 news were scraped from cryptopotato.com
# ### 60 news were scraped from Coinjournal.com
# ### 29 news were scraped from cryptotimes.io
# ### 73 news were scraped from newsbtc.com
# ### 152 news were scraped from cnbc.com

# %%
# !pip install beautifulsoup4

# %%
import requests
import bs4
from bs4 import BeautifulSoup

# %%
request = requests.get('https://coinjournal.net/')
print(type(request))
# Out:
# <class 'requests.models.Response'>

# %%
soup = BeautifulSoup(request.text, 'html.parser')

# %%
print(soup.title)
# Out:
# <title>CoinJournal: Latest Crypto News, Altcoin News and Cryptocurrency Comparison</title>

# %%
anchor = soup.find_all('h2')
anchor
# Out:
# [<h2 class="text-3xl lg:text-4xl font-serif mb-6">Latest Crypto News</h2>,
#  <h2 class="block font-sans font-medium text-lg md:text-xl mb-0"><b>Self-custodial Bitcoin staking protocol Babylon announces mainnet</b></h2>,
#  <h2 class="block font-sans font-medium text-lg md:text-xl mb-0"><b>AC Milan inks new sponsorship deal with crypto exchange, Bitpanda</b></h2>,
#  <h2 class="block font-sans font-medium text-lg md:text-xl mb-0"><b>Bitwise expands into Europe with acquisition of ETC Group</b></h2>,
#  <h2 class="block w-full font-sans font-medium text-lg md:text-2xl lg:text-3xl mb-3"><b>Binance to support Frontier (FRONT) token swap and rebranding</b></h2>,
#  <h2 class="mb-0 font-sans font-medium text-sm md:text-xl lg:text-base"><b><a href="https://coinjournal.net/news/russias-largest-search-engine-yandex-bans-crypto-ads/">Russia’s largest search engine Yandex bans crypto ads</a></b></h2>,
# ...

# %%
headline_news = []
for headline in anchor:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())

# %%
headline_news
# Out:
# ['Latest Crypto News',
#  'Self-custodial Bitcoin staking protocol Babylon announces mainnet',
#  'AC Milan inks new sponsorship deal with crypto exchange, Bitpanda',
#  'Bitwise expands into Europe with acquisition of ETC Group',
#  'Binance to support Frontier (FRONT) token swap and rebranding',
#  'Russia’s largest search engine Yandex bans crypto ads',
#  'HashKey Group taps TON mini-game Catizen as first Web3 partner',
#  'Tether expands USDT to the Aptos blockchain',
#  "CoinJournal's cryptocurrency analysis and market insights are trusted by leading publishers and global brands including",
#  'Bitcoin News',
#  'Toncoin signals bullish momentum as Bitcoin Dogs gears for its debut on three exchanges',
#  'Bitcoin Dogs to list on 3 major exchanges: Will 0DOG price explode?',
#  'South Korea’s national pension fund buys $34M of MicroStrategy shares',
#  'After raising over $13M in presale Bitcoin Dogs will list on three exchanges on August 21',
#  'Ethereum News',
# ...

# %%
# creating a dataframe with the extracted headlines
import pandas as pd
news_df = pd.DataFrame({'headline_news':headline_news})
news_df
# Out:
#                                         headline_news
# 0                                  Latest Crypto News
# 1   Self-custodial Bitcoin staking protocol Babylo...
# 2   AC Milan inks new sponsorship deal with crypto...
# 3   Bitwise expands into Europe with acquisition o...
# 4   Binance to support Frontier (FRONT) token swap...
# ..                                                ...
# 59                                     Press Releases
# 60  DOGS Partners with Bitget for Gas-Free Airdrop...
# 61  Holonym Foundation Emerges with $5.5M Seed Fun...
# 62  Blockchain Life 2024 in Dubai unveils first sp...
# 63  Bitget Wallet Hits 30 Million Users, Outpacing...
#
# [64 rows x 1 columns]

# %%
news_df.drop(index = 0, inplace = True)

# %%
news_df
# Out:
#                                         headline_news
# 1   Bitcoin miner Marathon Digital is mining Kaspa...
# 2   Cryptocurrencies waver as focus shifts to BitB...
# 3   Cryptocurrencies waver as focus shifts to BitB...
# 4   US government transfers 3,940 BTC worth $241 m...
# 5                                        Bitcoin News
# 6   German’s BKA transfers more Bitcoin to exchang...
# 7   Crypto Fear and Greed Index hits 30, lowest le...
# 8   Donald Trump receives $2M Bitcoin donation fro...
# 9   Bitcoin stays above $65k as Bitbot unveils its...
# 10  Riot Platforms wants to buy Bitfarms for $950 ...
# 11  Notcoin price soars after beating Bitcoin in v...
# 12  UK High Court Judge rules against Craig Wright...
# 13                                      Ethereum News
# 14  SEC chair says S-1 approvals for spot Ether ET...
# 15  Franklin Templeton proposes a 0.19% fee in its...
# 16  Hashdex has withdrawn its Ethereum ETF applica...
# ...

# %%
news_df.drop(index = [5,13,18,23,28,33,40,45,50,55], inplace = True)

# %%
news_df
# Out:
#                                         headline_news
# 1   Bitcoin miner Marathon Digital is mining Kaspa...
# 2   Cryptocurrencies waver as focus shifts to BitB...
# 3   Cryptocurrencies waver as focus shifts to BitB...
# 4   US government transfers 3,940 BTC worth $241 m...
# 6   German’s BKA transfers more Bitcoin to exchang...
# 7   Crypto Fear and Greed Index hits 30, lowest le...
# 8   Donald Trump receives $2M Bitcoin donation fro...
# 9   Bitcoin stays above $65k as Bitbot unveils its...
# 10  Riot Platforms wants to buy Bitfarms for $950 ...
# 11  Notcoin price soars after beating Bitcoin in v...
# 12  UK High Court Judge rules against Craig Wright...
# 14  SEC chair says S-1 approvals for spot Ether ET...
# 15  Franklin Templeton proposes a 0.19% fee in its...
# 16  Hashdex has withdrawn its Ethereum ETF applica...
# 17    Here’s why Ondo Finance (ONDO) price is soaring
# 19  Light Protocol and Helius Labs launch ZK Compr...
# ...

# %% [markdown]
# ###  60 news were scraped from Coinjournal.com

# %% [markdown]
# ### Cryptotimes.io scraping

# %%
request = requests.get('https://www.cryptotimes.io/')
print(type(request))
# Out:
# <class 'requests.models.Response'>

# %%
soup = BeautifulSoup(request.content, 'html.parser')

# %%
print(soup.title)
# Out:
# <title>The Crypto Times: Your One-Stop Destination for Crypto News</title>

# %%
anchor = soup.find_all('a',{"class":'p-flink'})
anchor
# Out:
# [<a class="p-flink" href="https://www.cryptotimes.io/2024/08/17/check-speculative-price-of-dogs-ahead-of-airdrop-and-listing/" title="Check Speculative Price of $DOGS ahead of Airdrop and Listing">
#  <picture class="featured-img wp-post-image" decoding="async" loading="eager">
#  <source sizes="(max-width: 860px) 100vw, 860px" srcset="https://www.cryptotimes.io/wp-content/uploads/2024/08/Check-Speculative-Price-of-DOGS-ahead-of-Airdrop-and-Listing-860x484.jpg.webp 860w, https://www.cryptotimes.io/wp-content/uploads/2024/08/Check-Speculative-Price-of-DOGS-ahead-of-Airdrop-and-Listing.jpg.webp 1280w" type="image/webp"/>
# ...

# %%
title = []
for attr in anchor:
    #url.append(attr['href'])
    title.append(attr['title'])
    print("Url: ", attr['href'])
    print("Title: ", attr['title'])
    print("_____________________")
# Out:
# Url:  https://www.cryptotimes.io/2024/08/17/check-speculative-price-of-dogs-ahead-of-airdrop-and-listing/
# Title:  Check Speculative Price of $DOGS ahead of Airdrop and Listing
# _____________________
# Url:  https://www.cryptotimes.io/2024/08/16/trump-jr-releases-telegram-channel-for-the-official-crypto-project/
# Title:  Trump Jr. Releases Telegram Channel for the Official Crypto Project
# _____________________
# Url:  https://www.cryptotimes.io/2024/08/16/hundreds-of-wazirx-investors-to-file-police-complaints-against-exchange/
# Title:  Hundreds of WazirX Investors to file police complaints against exchange
# _____________________
# Url:  https://www.cryptotimes.io/2024/08/16/million-dollar-airdrop-payouts-at-eigenlabs-spark-ethics-concerns/
# Title:  Million Dollar Airdrop Payouts at EigenLabs Spark Ethics Concerns
# _____________________
# Url:  https://www.cryptotimes.io/2024/08/17/openai-bans-iranian-accounts-for-u-s-election-fake-news/
# ...

# %%
title
# Out:
# ['Check Speculative Price of $DOGS ahead of Airdrop and Listing',
#  'Trump Jr. Releases Telegram Channel for the Official Crypto Project',
#  'Hundreds of WazirX Investors to file police complaints against exchange',
#  'Million Dollar Airdrop Payouts at EigenLabs Spark Ethics Concerns',
#  'OpenAI Bans Iranian Accounts for U.S. Election Fake News',
#  'In U.S. Politics, NFTs are in, Posters are out!',
#  'Why Hamster Kombat Airdrop is Delayed: Key Reasons',
#  'Here’s Why WazirX Keeps Delaying Withdrawal Of Investor Funds',
#  'Nigeria on Brink: Why are Nigerians Moving Towards Crypto Trading?',
#  'Check Speculative Price of $DOGS ahead of Airdrop and Listing',
#  'Trump Jr. Releases Telegram Channel for the Official Crypto Project',
#  'Hundreds of WazirX Investors to file police complaints against exchange',
#  'Million Dollar Airdrop Payouts at EigenLabs Spark Ethics Concerns',
#  'OpenAI Bans Iranian Accounts for U.S. Election Fake News',
# ...

# %%
df2 = pd.DataFrame({'headline_news':title})
df2
# Out:
#                                         headline_news
# 0   Check Speculative Price of $DOGS ahead of Aird...
# 1   Trump Jr. Releases Telegram Channel for the Of...
# 2   Hundreds of WazirX Investors to file police co...
# 3   Million Dollar Airdrop Payouts at EigenLabs Sp...
# 4   OpenAI Bans Iranian Accounts for U.S. Election...
# ..                                                ...
# 56  Breaking: Pixelverse Rolls Out Phase 3 With Ne...
# 57  Google Sued for $5M Over Malicious Crypto Wall...
# 58  How North Korean Hackers stole $1.3 M by posin...
# 59  Styx Stealer Malware Targets Cryptocurrency Users
# 60  Bitcoin Fog Founder Begs Mercy Post Money Laun...
#
# [61 rows x 1 columns]

# %%
df2 = df2.drop_duplicates()

# %%
df2 = df2.reset_index(drop = True)

# %%
df2
# Out:
#                                         headline_news
# 0   Check Speculative Price of $DOGS ahead of Aird...
# 2   Hundreds of WazirX Investors to file police co...
# 3   Million Dollar Airdrop Payouts at EigenLabs Sp...
# 4   OpenAI Bans Iranian Accounts for U.S. Election...
# 5     In U.S. Politics, NFTs are in, Posters are out!
# 8   Nigeria on Brink: Why are Nigerians Moving Tow...
# 9   Tron Surpasses Cardano to Enter the Top Ten Cr...
# 10  Crypto Enthusiasm Among Young Voters Set to Sh...
# 11    Toncoin’s 9% Surge Defies Crypto Market Decline
# 12  Shaquille O’Neal’s Astral NFT Case Partially D...
# 13  CoinDCX to list $DOGS token on August 20: Chec...
# 14  Exploring The Open Network ‘TON Chain’ and Pow...
# 15  Analyst Doubts Bitcoin Will Reach 70% Dominanc...
# 16  Bitcoin Miners Could Earn $13.9 Billion Yearly...
# 17  PayPal’s Peter Thiel Warns Society Isn’t Ready...
# 18  Spot Bitcoin ETFs in U.S. Draw Major Investor ...
# ...

# %%
df2 = df2.reset_index(drop = True)
df2
# Out:
#                                         headline_news
# 0   Check Speculative Price of $DOGS ahead of Aird...
# 1   Hundreds of WazirX Investors to file police co...
# 2   Million Dollar Airdrop Payouts at EigenLabs Sp...
# 3   OpenAI Bans Iranian Accounts for U.S. Election...
# 4     In U.S. Politics, NFTs are in, Posters are out!
# 5   Nigeria on Brink: Why are Nigerians Moving Tow...
# 6   Tron Surpasses Cardano to Enter the Top Ten Cr...
# 7   Crypto Enthusiasm Among Young Voters Set to Sh...
# 8     Toncoin’s 9% Surge Defies Crypto Market Decline
# 9   Shaquille O’Neal’s Astral NFT Case Partially D...
# 10  CoinDCX to list $DOGS token on August 20: Chec...
# 11  Exploring The Open Network ‘TON Chain’ and Pow...
# 12  Analyst Doubts Bitcoin Will Reach 70% Dominanc...
# 13  Bitcoin Miners Could Earn $13.9 Billion Yearly...
# 14  PayPal’s Peter Thiel Warns Society Isn’t Ready...
# 15  Spot Bitcoin ETFs in U.S. Draw Major Investor ...
# ...

# %% [markdown]
# ### 29 news were scraped from cryptotimes.io

# %%
anchor = soup.find_all("body")
anchor
# Out:
# [<body class="home page-template-default page page-id-1387 wp-embed-responsive elementor-default elementor-kit-6 elementor-page elementor-page-1387 menu-ani-1 hover-ani-3 btn-ani-1 is-rm-1 lmeta-dot loader-1 is-hd-rb_template is-backtop none-m-backtop is-mstick is-smart-sticky" data-theme="default">
#  <script>
#              (function () {
#                  let currentMode = null;
#                  const darkModeID = 'RubyDarkMode';
#  				                currentMode = navigator.cookieEnabled ? localStorage.getItem(darkModeID) || null : 'default';
#                  if (!currentMode) {
#  					                    currentMode = 'default';
#                      localStorage.setItem(darkModeID, 'default');
#  					                }
#                  document.body.setAttribute('data-theme', currentMode === 'dark' ? 'dark' : 'default');
#  				            })();
#  		</script>
#  <!-- Google Tag Manager (noscript) -->
#  <noscript>
# ...

# %%
news_df = pd.concat([news_df,df2],
                   axis = 0)
news_df
# Out:
#                                         headline_news
# 0                                  Latest Crypto News
# 1   Self-custodial Bitcoin staking protocol Babylo...
# 2   AC Milan inks new sponsorship deal with crypto...
# 3   Bitwise expands into Europe with acquisition o...
# 4   Binance to support Frontier (FRONT) token swap...
# ..                                                ...
# 40  Breaking: Pixelverse Rolls Out Phase 3 With Ne...
# 41  Google Sued for $5M Over Malicious Crypto Wall...
# 42  How North Korean Hackers stole $1.3 M by posin...
# 43  Styx Stealer Malware Targets Cryptocurrency Users
# 44  Bitcoin Fog Founder Begs Mercy Post Money Laun...
#
# [99 rows x 1 columns]

# %%
news_df = news_df.reset_index(drop = True)
news_df
# Out:
#                                         headline_news
# 0                                  Latest Crypto News
# 1   Self-custodial Bitcoin staking protocol Babylo...
# 2   AC Milan inks new sponsorship deal with crypto...
# 3   Bitwise expands into Europe with acquisition o...
# 4   Binance to support Frontier (FRONT) token swap...
# ..                                                ...
# 94  Breaking: Pixelverse Rolls Out Phase 3 With Ne...
# 95  Google Sued for $5M Over Malicious Crypto Wall...
# 96  How North Korean Hackers stole $1.3 M by posin...
# 97  Styx Stealer Malware Targets Cryptocurrency Users
# 98  Bitcoin Fog Founder Begs Mercy Post Money Laun...
#
# [99 rows x 1 columns]

# %% [markdown]
# ### newsbtc.com scraping

# %%
request = requests.get('https://www.newsbtc.com/')
print(type(request))
# Out:
# <class 'requests.models.Response'>

# %%
soup = BeautifulSoup(request.content, 'html.parser')
print(soup.title)
# Out:
# <title>The Latest Bitcoin News &amp; Expert Crypto Insights | NewsBTC</title>

# %%
anchor = soup.find_all("h4",{"class":'block-article__title'})
anchor
# Out:
# [<h4 class="block-article__title">
#  Crypto Experts Believe This New ICO Will Surpass Dogecoin (DOGE) Becoming The Biggest Memecoin</h4>,
#  <h4 class="block-article__title">
#  Crypto Liquidations Cross $1 Billion As Bitcoin Crashes To $51,000</h4>,
#  <h4 class="block-article__title">
#  Bitcoin Hashrate Nears Record Levels Amidst Price Decline – Details</h4>,
#  <h4 class="block-article__title">
#  Trump Floats Bitcoin Payments As Solution To $35 Trillion US Debt Crisis</h4>,
#  <h4 class="block-article__title">
#  Mpeppe’s Utility Boost Their Popularity As Pepe Unchained Investors Join The Pre-sale</h4>,
#  <h4 class="block-article__title">
#  Mpeppe’s (MPEPE) Impressive Performance Has Gathered The Attention Of XRP Whales</h4>,
#  <h4 class="block-article__title">
#  PEPU &amp; MPEPE: These Two Powerful ICO’s Are Surging Here’s Why Now Is The Right Time to Invest</h4>,
#  <h4 class="block-article__title">
# ...

# %%
headline_news = []
for headline in anchor:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())

# %%
headline_news
# Out:
# ['Crypto Experts Believe This New ICO Will Surpass Dogecoin (DOGE) Becoming The Biggest Memecoin',
#  'Crypto Liquidations Cross $1 Billion As Bitcoin Crashes To $51,000',
#  'Bitcoin Hashrate Nears Record Levels Amidst Price Decline – Details',
#  'Trump Floats Bitcoin Payments As Solution To $35 Trillion US Debt Crisis',
#  'Mpeppe’s Utility Boost Their Popularity As Pepe Unchained Investors Join The Pre-sale',
#  'Mpeppe’s (MPEPE) Impressive Performance Has Gathered The Attention Of XRP Whales',
#  'PEPU & MPEPE: These Two Powerful ICO’s Are Surging Here’s Why Now Is The Right Time to Invest',
#  'Who Will Provide More Long Term Profits Pepe Unchained or Mpeppe, Experts Weigh in',
#  'Dogecoin (DOGE) vs Mpeppe (MPEPE): Why Market Experts Are More Excited At MPEPE Then DOGE',
#  'Dogecoin (DOGE)’s Community Set Become Loyal Mpeppe (MPEPE) Investors Due To Massive Profits',
#  'Ethereum (ETH) and Mpeppe (MPEPE) Holder Are Happy as Both Are Predicted to Explode By 300x',
# ...

# %%
df3 = pd.DataFrame({'headline_news':headline_news})
df3
# Out:
#                                         headline_news
# 0   Crypto Experts Believe This New ICO Will Surpa...
# 1   Crypto Liquidations Cross $1 Billion As Bitcoi...
# 2   Bitcoin Hashrate Nears Record Levels Amidst Pr...
# 3   Trump Floats Bitcoin Payments As Solution To $...
# 4   Mpeppe’s Utility Boost Their Popularity As Pep...
# ..                                                ...
# 61  Is Now the Time to Buy Bitcoin? Top Analysts P...
# 62  BTC’s Next Objective? Analyst Eyes Crucial $70...
# 63  Bitcoin Traders Cautious Despite Massive Stabl...
# 64  Reinventing Bitcoin Liquidity with TerpLayer’s...
# 65  Tough Battles Between The Bulls and The Bears:...
#
# [66 rows x 1 columns]

# %%
### 73 news were scaped from newsbtc.com

# %%
news_df = pd.concat([news_df,df3],
                   axis = 0)
news_df
# Out:
#                                         headline_news
# 0                                  Latest Crypto News
# 1   Self-custodial Bitcoin staking protocol Babylo...
# 2   AC Milan inks new sponsorship deal with crypto...
# 3   Bitwise expands into Europe with acquisition o...
# 4   Binance to support Frontier (FRONT) token swap...
# ..                                                ...
# 61  Is Now the Time to Buy Bitcoin? Top Analysts P...
# 62  BTC’s Next Objective? Analyst Eyes Crucial $70...
# 63  Bitcoin Traders Cautious Despite Massive Stabl...
# 64  Reinventing Bitcoin Liquidity with TerpLayer’s...
# 65  Tough Battles Between The Bulls and The Bears:...
#
# [165 rows x 1 columns]

# %%
news_df = news_df.reset_index(drop = True)

# %%
news_df
# Out:
#                                          headline_news
# 0                                   Latest Crypto News
# 1    Self-custodial Bitcoin staking protocol Babylo...
# 2    AC Milan inks new sponsorship deal with crypto...
# 3    Bitwise expands into Europe with acquisition o...
# 4    Binance to support Frontier (FRONT) token swap...
# ..                                                 ...
# 160  Is Now the Time to Buy Bitcoin? Top Analysts P...
# 161  BTC’s Next Objective? Analyst Eyes Crucial $70...
# 162  Bitcoin Traders Cautious Despite Massive Stabl...
# 163  Reinventing Bitcoin Liquidity with TerpLayer’s...
# 164  Tough Battles Between The Bulls and The Bears:...
#
# [165 rows x 1 columns]

# %%
request = requests.get('https://cryptopotato.com/')
print(type(request))
# Out:
# <class 'requests.models.Response'>

# %%
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
# Out:
# <title>CryptoPotato - Bitcoin &amp; Altcoins, Crypto News and Guides</title>

# %%
anchor = soup.find_all('div')
anchor
# Out:
# [<div class="wide" id="container">
#  <section id="top-bar">
#  <div class="container">
#  <div class="pull-left">
#  </div>
#  <div class="pull-right">
#  </div>
#  </div><!-- .container -->
#  </section>
#  <header class="logo-left" id="header" role="banner">
#  <div class="container">
#  <div class="logo">
#  <div class="logo-img awd-hidden-phone">
#  <a href="https://cryptopotato.com/" rel="home"><img alt="CryptoPotato" class="logo-img-primary" src="https://cryptopotato.com/wp-content/uploads/2022/06/cplogo3.png"/></a>
#  </div>
#  <div class="logo-img awd-visible-phone">
#  <a href="https://cryptopotato.com/" rel="home"><img alt="CryptoPotato" class="logo-img-primary" src="/wp-content/uploads/cplogo3m.png"/></a>
#  </div>
#  <button class="navbar-toggle visible-xs" data-target=".navbar-collapse" data-toggle="collapse" type="button">
#  <span class="sr-only">Toggle navigation</span>
#  <span class="icon-bar"></span>
#  <span class="icon-bar"></span>
# ...

# %%
anchor2 = soup.find_all('h3',{"class": "media-heading entry-title"})
anchor2
# Out:
# [<h3 class="media-heading entry-title"><a href="https://cryptopotato.com/shortest-bull-run-in-history-or-big-bitcoin-rally-analyst-debate-btcs-current-state/">Shortest Bull Run in History or Big Bitcoin Rally? Analyst Debate BTC’s Current State</a></h3>,
#  <h3 class="media-heading entry-title"><a href="https://cryptopotato.com/surging-bond-market-portends-another-bitcoin-bull-run/">Surging Bond Market Portends Another Bitcoin Bull Run</a></h3>,
#  <h3 class="media-heading entry-title"><a href="https://cryptopotato.com/bitcoin-slips-towards-bear-market-after-losing-these-key-support-levels-analysts/">Bitcoin Slips Towards Bear Market After Losing These Key Support Levels: Analysts</a></h3>,
#  <h3 class="media-heading entry-title"><a href="https://cryptopotato.com/seven-arrested-in-malaysia-for-bitcoin-mining-electricity-theft-52-rigs-seized/">Seven Arrested in Malaysia for Bitcoin Mining Electricity Theft; 52 Rigs Seized</a></h3>,
# ...

# %%
headline_news = []
for headline in anchor2:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())

# %%
headline_news
# Out:
# ['Shortest Bull Run in History or Big Bitcoin Rally? Analyst Debate BTC’s Current State',
#  'Surging Bond Market Portends Another Bitcoin Bull Run',
#  'Bitcoin Slips Towards Bear Market After Losing These Key Support Levels: Analysts',
#  'Seven Arrested in Malaysia for Bitcoin Mining Electricity Theft; 52 Rigs Seized',
#  'Decline in Solana Meme Coins Sparks Record $39M Outflows Amid Bearish Shift',
#  'Tether to Launch USDT on Aptos Network, Promising Ultra-Low Gas Fees and Global Accessibility',
#  'Hut 8 Reports $71.9M Q2 Loss Despite 72% Surge in Bitcoin Mining Revenue',
#  'A Shocking Number of Meme Coins Have Failed in 2024: Study',
#  'Experts Refute Damning IMF ‘Attack Piece’ on Crypto Mining',
#  'TeraWulf Reports 21% Drop in Bitcoin Mining but Revenue Surpasses Estimates in Q2',
#  'Masked Intruders Escape with $2M in Crypto: Thai Police Launched Investigation',
#  'Big News for Bitcoin Adoption? Norwegian Government Increases Sovereign Fund’s BTC Exposure',
# ...

# %%
df4 = pd.DataFrame({
    "headline_news":headline_news
})
df4
# Out:
#                                         headline_news
# 0   Shortest Bull Run in History or Big Bitcoin Ra...
# 1   Surging Bond Market Portends Another Bitcoin B...
# 2   Bitcoin Slips Towards Bear Market After Losing...
# 3   Seven Arrested in Malaysia for Bitcoin Mining ...
# 4   Decline in Solana Meme Coins Sparks Record $39...
# 5   Tether to Launch USDT on Aptos Network, Promis...
# 6   Hut 8 Reports $71.9M Q2 Loss Despite 72% Surge...
# 7   A Shocking Number of Meme Coins Have Failed in...
# 8   Experts Refute Damning IMF ‘Attack Piece’ on C...
# 9   TeraWulf Reports 21% Drop in Bitcoin Mining bu...
# 10  Masked Intruders Escape with $2M in Crypto: Th...
# 11  Big News for Bitcoin Adoption? Norwegian Gover...
# 12  Meme Coin Market Looking Grim: 4 of Top 6 Lose...
# 13  TRON Meme Coin Mania Accelerates: Over 1,000 M...
# 14  These Big U.S. Banks Bought Spot Bitcoin ETFs ...
# 15  Overall Illicit Activity in Crypto Falls 20% Y...
# ...

# %%
news_df = pd.concat([news_df,df4],
                   axis = 0)
news_df = news_df.reset_index(drop = True)

# %%
news_df
# Out:
#                                          headline_news
# 0                                   Latest Crypto News
# 1    Self-custodial Bitcoin staking protocol Babylo...
# 2    AC Milan inks new sponsorship deal with crypto...
# 3    Bitwise expands into Europe with acquisition o...
# 4    Binance to support Frontier (FRONT) token swap...
# ..                                                 ...
# 188  Crypto Gamers Backing PlayDoge as Viral P2E Pr...
# 189  Pepe Unchained Breaks $9M Barrier in ICO, Anal...
# 190  Is it too Late to Get Into Neiro Ethereum? Exp...
# 191  Crypto Analyst Says Neiro Ethereum Could Explo...
# 192  Pepe Unchained Surges to $8.7M in Presale as L...
#
# [193 rows x 1 columns]

# %%
anchor3 = soup.find_all('header',{"class": "ft-post-title"})
anchor3
# Out:
# [<header class="ft-post-title">
#  <h2>
#  <a href="https://cryptopotato.com/bitcoin-price-stalls-below-59k-in-anticipation-of-this-weeks-fed-minutes-market-watch/">Bitcoin Price Stalls Below $59K in Anticipation of This Week's Fed Minutes (Market Watch)</a>
#  </h2>
#  </header>,
#  <header class="ft-post-title">
#  <h2>
#  <a href="https://cryptopotato.com/all-eyes-on-fed-speech-3-things-to-watch-in-week-ahead-for-crypto-markets/">All Eyes on Fed Speech: 3 Things to Watch in Week Ahead For Crypto Markets</a>
#  </h2>
#  </header>,
#  <header class="ft-post-title">
#  <h2>
#  <a href="https://cryptopotato.com/is-the-bitcoin-price-in-grave-danger-3-bearish-and-2-bullish-signs-for-btc-to-watch/">Is the Bitcoin Price in Grave Danger? 3 Bearish And 2 Bullish Signs For BTC to Watch</a>
#  </h2>
#  </header>,
#  <header class="ft-post-title">
#  <h2>
# ...

# %%
headline_news = []
for headline in anchor3:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())

# %%
headline_news
# Out:
# ["Bitcoin Price Stalls Below $59K in Anticipation of This Week's Fed Minutes (Market Watch)",
#  'All Eyes on Fed Speech: 3 Things to Watch in Week Ahead For Crypto Markets',
#  'Is the Bitcoin Price in Grave Danger? 3 Bearish And 2 Bullish Signs For BTC to Watch',
#  "Banking Giants Disclose Bitcoin Exposure but Crypto Markets Tank: This Week's Recap"]

# %%
df5 = pd.DataFrame({
    'headline_news':headline_news
})

df5
# Out:
#                                        headline_news
# 0  Bitcoin Price Stalls Below $59K in Anticipatio...
# 1  All Eyes on Fed Speech: 3 Things to Watch in W...
# 2  Is the Bitcoin Price in Grave Danger? 3 Bearis...
# 3  Banking Giants Disclose Bitcoin Exposure but C...

# %%
news_df = pd.concat([news_df,df5],
                   axis = 0)
news_df = news_df.reset_index(drop = True)
news_df
# Out:
#                                          headline_news
# 0                                   Latest Crypto News
# 1    Self-custodial Bitcoin staking protocol Babylo...
# 2    AC Milan inks new sponsorship deal with crypto...
# 3    Bitwise expands into Europe with acquisition o...
# 4    Binance to support Frontier (FRONT) token swap...
# ..                                                 ...
# 192  Pepe Unchained Surges to $8.7M in Presale as L...
# 193  Bitcoin Price Stalls Below $59K in Anticipatio...
# 194  All Eyes on Fed Speech: 3 Things to Watch in W...
# 195  Is the Bitcoin Price in Grave Danger? 3 Bearis...
# 196  Banking Giants Disclose Bitcoin Exposure but C...
#
# [197 rows x 1 columns]

# %%
request = requests.get('https://cryptopotato.com/crypto-news/')
print(type(request))
# Out:
# <class 'requests.models.Response'>

# %%
soup =BeautifulSoup(request.text, 'html.parser')
print(soup.title)
# Out:
# <title>Crypto News Today | CryptoPotato</title>

# %%
anc = soup.find_all('h3')
anc
# Out:
# [<h3 class="rpwe-title"><a data-wpel-link="internal" href="https://cryptopotato.com/shortest-bull-run-in-history-or-big-bitcoin-rally-analyst-debate-btcs-current-state/" rel="bookmark" title="Permalink to Shortest Bull Run in History or Big Bitcoin Rally? Analyst Debate BTC’s Current State">Shortest Bull Run in History or Big Bitcoin Rally? Analyst Debate BTC’s Current State</a></h3>,
#  <h3 class="rpwe-title"><a data-wpel-link="internal" href="https://cryptopotato.com/surging-bond-market-portends-another-bitcoin-bull-run/" rel="bookmark" title="Permalink to Surging Bond Market Portends Another Bitcoin Bull Run">Surging Bond Market Portends Another Bitcoin Bull Run</a></h3>,
# ...

# %%
headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())

# %%
headline_news
# Out:
# ['Shortest Bull Run in History or Big Bitcoin Rally? Analyst Debate BTC’s Current State',
#  'Surging Bond Market Portends Another Bitcoin Bull Run',
#  'Bitcoin Slips Towards Bear Market After Losing These Key Support Levels: Analysts',
#  'Seven Arrested in Malaysia for Bitcoin Mining Electricity Theft; 52 Rigs Seized',
#  'Unexpected Altcoin Explodes by 60% Daily Following Support From Binance: Details',
#  'Decline in Solana Meme Coins Sparks Record $39M Outflows Amid Bearish Shift',
#  '4 Reasons to be Bullish on Bitcoin in 2024 (Opinion)',
#  'Calm Before the Storm: XRP on the Verge of a Big Move Around This Critical Level (Ripple Price Analysis)',
#  'Massive Rally for Bitcoin Only Possible if This Level Falls: BTC Price Analysis',
#  'Tether to Launch USDT on Aptos Network, Promising Ultra-Low Gas Fees and Global Accessibility',
#  'Huge Breakout in the Cards for Ripple (XRP) Price: Analyst',
# ...

# %%
df6 = pd.DataFrame({
    'headline_news':headline_news
})
df6
# Out:
#                                         headline_news
# 0   Shortest Bull Run in History or Big Bitcoin Ra...
# 1   Surging Bond Market Portends Another Bitcoin B...
# 2   Bitcoin Slips Towards Bear Market After Losing...
# 3   Seven Arrested in Malaysia for Bitcoin Mining ...
# 4   Unexpected Altcoin Explodes by 60% Daily Follo...
# 5   Decline in Solana Meme Coins Sparks Record $39...
# 6   4 Reasons to be Bullish on Bitcoin in 2024 (Op...
# 7   Calm Before the Storm: XRP on the Verge of a B...
# 8   Massive Rally for Bitcoin Only Possible if Thi...
# 9   Tether to Launch USDT on Aptos Network, Promis...
# 10  Huge Breakout in the Cards for Ripple (XRP) Pr...
# 11  Bitcoin Price Stalls Below $59K in Anticipatio...
# 12  Shiba Inu Burn Rate Plummets by 90%: Is the SH...
# 13  Ripple (XRP) Price Explodes by Over 5,000% to ...
# 14  Important Ripple v SEC Lawsuit Updates, Bearis...
# 15  All Eyes on Fed Speech: 3 Things to Watch in W...
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/5/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 5 of 2266 | CryptoPotato</title>

# %%
anc = soup.find_all('h3')
anc
# Out:
# [<h3 class="media-heading">
#  <a href="https://cryptopotato.com/which-crypto-will-perform-better-in-2024-xrp-shib-or-ada-chatgpt-speculates/">Which Crypto Will Perform Better in 2024: XRP, SHIB, or ADA? ChatGPT Speculates</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/important-shiba-inu-shib-announcement/">Important Shiba Inu (SHIB) Announcement</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/bitcoin-eyes-60k-but-these-altcoins-outperform-weekend-watch/">Bitcoin Eyes $60K But These Altcoins Outperform (Weekend Watch)</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/fidelity-joins-tokenization-race-researching-stablecoins-and-digital-treasury-products/">Fidelity Joins Tokenization Race Researching Stablecoins and Digital Treasury Products</a>
#  </h3>,
#  <h3 class="media-heading">
# ...

# %%
headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())

# %%
headline_news
# Out:
# ['Which Crypto Will Perform Better in 2024: XRP, SHIB, or ADA? ChatGPT Speculates',
#  'Important Shiba Inu (SHIB) Announcement',
#  'Bitcoin Eyes $60K But These Altcoins Outperform (Weekend Watch)',
#  'Fidelity Joins Tokenization Race Researching Stablecoins and Digital Treasury Products',
#  'New Inflation Read Signals Fed Rate Cut in Tailwind for Bitcoin’s Price',
#  'US Mortgages Hit New Lows: Here’s How Much House You Can Get for Your Bitcoin',
#  'North Korean Devs Used Fake Identities to Steal From Crypto Project: ZachXBT',
#  'Is Trump Really A Bitcoiner? Here’s What Crypto He Actually Owns',
#  'Tron Network Outpaces Ethereum in Revenue Over the Past 90 Days',
#  'Dubai Says Yes to Crypto Salaries']

# %%
df7 = pd.DataFrame({'headline_news':headline_news})
df7
# Out:
#                                        headline_news
# 0  Which Crypto Will Perform Better in 2024: XRP,...
# 1            Important Shiba Inu (SHIB) Announcement
# 2  Bitcoin Eyes $60K But These Altcoins Outperfor...
# 3  Fidelity Joins Tokenization Race Researching S...
# 4  New Inflation Read Signals Fed Rate Cut in Tai...
# 5  US Mortgages Hit New Lows: Here’s How Much Hou...
# 6  North Korean Devs Used Fake Identities to Stea...
# 7  Is Trump Really A Bitcoiner? Here’s What Crypt...
# 8  Tron Network Outpaces Ethereum in Revenue Over...
# 9                  Dubai Says Yes to Crypto Salaries

# %% [markdown]
# * Df7 yet to be concat

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/6/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 6 of 2266 | CryptoPotato</title>

# %%
anc = soup.find_all('h3')
anc
# Out:
# [<h3 class="media-heading">
#  <a href="https://cryptopotato.com/ethereum-gas-fee-slumps-to-lowest-level-in-five-years-data/">Ethereum Gas Fee Slumps to Lowest Level in Five Years: Data</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/banking-giants-disclose-bitcoin-exposure-but-crypto-markets-tank-this-weeks-recap/">Banking Giants Disclose Bitcoin Exposure but Crypto Markets Tank: This Week’s Recap</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/ripple-price-analysis-xrp-bulls-want-to-aim-0-64-but-theres-a-catch/">Ripple Price Analysis: XRP Bulls Want to Aim $0.64 But There’s a Catch</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/is-this-the-new-meme-coin-mania/">Is This The New Meme Coin Mania?</a>
#  </h3>,
#  <h3 class="media-heading">
# ...

# %%
headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())

# %%
headline_news
# Out:
# ['Ethereum Gas Fee Slumps to Lowest Level in Five Years: Data',
#  'Banking Giants Disclose Bitcoin Exposure but Crypto Markets Tank: This Week’s Recap',
#  'Ripple Price Analysis: XRP Bulls Want to Aim $0.64 But There’s a Catch',
#  'Is This The New Meme Coin Mania?',
#  '90% Chance for Ripple (XRP) to Lose Against the SEC on Appeal? Fmr. Senate Staffer Comments',
#  'World’s Third-Largest Pension Fund NPS Acquires $34M of MicroStrategy Shares',
#  'Bitcoin Plummets to $56K and Recovers, Altcoins Volatile (Market Watch)',
#  'Crypto Price Analysis August-16: ETH, XRP, ADA, BNB, and SOL',
#  'Important Ripple v SEC Lawsuit Development Incoming?',
#  'Will Bitcoin Keep Falling After $1.4B BTC Options Expire?']

# %%
df8 = pd.DataFrame({'headline_news':headline_news})
df8
# Out:
#                                        headline_news
# 0  Ethereum Gas Fee Slumps to Lowest Level in Fiv...
# 1  Banking Giants Disclose Bitcoin Exposure but C...
# 2  Ripple Price Analysis: XRP Bulls Want to Aim $...
# 3                   Is This The New Meme Coin Mania?
# 4  90% Chance for Ripple (XRP) to Lose Against th...
# 5  World’s Third-Largest Pension Fund NPS Acquire...
# 6  Bitcoin Plummets to $56K and Recovers, Altcoin...
# 7  Crypto Price Analysis August-16: ETH, XRP, ADA...
# 8  Important Ripple v SEC Lawsuit Development Inc...
# 9  Will Bitcoin Keep Falling After $1.4B BTC Opti...

# %% [markdown]
# * DF8 yet to be concat

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/7/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 7 of 2266 | CryptoPotato</title>

# %%
anc = soup.find_all('h3')
anc
# Out:
# [<h3 class="media-heading">
#  <a href="https://cryptopotato.com/why-zcashs-price-topped-the-crypto-charts-last-week/">Why ZCash’s Price Topped the Crypto Charts Last Week?</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/binance-agrees-to-1-76m-settlement-with-brazilian-authorities/">Binance Agrees to $1.76M Settlement with Brazilian Authorities</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/majority-of-institutional-investors-held-or-increased-bitcoin-etf-positions-in-q2/">Majority of Institutional Investors Held or Increased Bitcoin ETF Positions in Q2</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/bitcoin-price-crashes-below-57k-as-total-liquidations-exceed-200-million/">Bitcoin Price Crashes Below $57K as Total Liquidations Exceed $200 Million</a>
#  </h3>,
#  <h3 class="media-heading">
# ...

# %%
headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df9 = pd.DataFrame({'headline_news':headline_news})
df9
# Out:
#                                        headline_news
# 0  Why ZCash’s Price Topped the Crypto Charts Las...
# 1  Binance Agrees to $1.76M Settlement with Brazi...
# 2  Majority of Institutional Investors Held or In...
# 3  Bitcoin Price Crashes Below $57K as Total Liqu...
# 4  State of Wisconsin Investment Board Increases ...
# 5  How Much Sahil Arora Profited by Creating Cele...
# 6  Centralized Exchanges Reclaimed by Hackers as ...
# 7  Marathon Digital Purchases $250M in Bitcoin (B...
# 8                   Important Pi Network (PI) Update
# 9  After the Ripple v. SEC Lawsuit Update: 3 Impl...

# %% [markdown]
# * DF9 yet to be concat

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/8/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 8 of 2266 | CryptoPotato</title>

# %%
anc = soup.find_all('h3')
anc
# Out:
# [<h3 class="media-heading">
#  <a href="https://cryptopotato.com/crypto-markets-shed-80-billion-daily-as-bitcoin-btc-slumps-to-58k-market-watch/">Crypto Markets Shed $80 Billion Daily as Bitcoin (BTC) Slumps to $58K (Market Watch)</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/cardano-ada-founder-charles-hoskinson-on-the-use-cases-of-artificial-intelligence-in-blockchain/">Cardano (ADA) Founder Charles Hoskinson on the Use Cases of Artificial Intelligence in Blockchain</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/important-shiba-inu-indicators-head-north-shib-price-recovery-incoming/">Important Shiba Inu Indicators Head North: SHIB Price Recovery Incoming?</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/morgan-stanley-becomes-fifth-largest-ibit-holder-with-188m-position/">Morgan Stanley Becomes Fifth Largest IBIT Holder With $188M Position</a>
#  </h3>,
# ...

# %%
headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df10 = pd.DataFrame({'headline_news':headline_news})
df10
# Out:
#                                        headline_news
# 0  Crypto Markets Shed $80 Billion Daily as Bitco...
# 1  Cardano (ADA) Founder Charles Hoskinson on the...
# 2  Important Shiba Inu Indicators Head North: SHI...
# 3  Morgan Stanley Becomes Fifth Largest IBIT Hold...
# 4  Goldman Sachs Currently Manages $419M in Bitco...
# 5  Jump Trading Offloads More Ethereum as ETH Pri...
# 6  Crypto.com Secures Historic Partnership With U...
# 7  Bitcoin Miner Core Scientific Upsizes Senior N...
# 8  Bitcoin Drops To $59,000 As US Government Move...
# 9  Important Binance Update Affecting This Popula...

# %% [markdown]
# * DF10 yet to be concat

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/9/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 9 of 2266 | CryptoPotato</title>
# [<h3 class="media-heading">
#  <a href="https://cryptopotato.com/investor-sentiment-uncertain-yet-bitcoins-hodling-trends-resurface-during-market-decline/">Investor Sentiment Uncertain, Yet Bitcoin’s HODLing Trends Resurface During Market Decline</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/dogecoin-doge-is-currently-the-most-profitable-meme-coin-what-about-shiba-inu-shib/">Dogecoin (DOGE) is Currently the Most-Profitable Meme Coin: What About Shiba Inu (SHIB)?</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/us-inflation-numbers-as-expected-bitcoin-registers-slight-volatility/">US Inflation Numbers as Expected, Bitcoin Registers Slight Volatility</a>
#  </h3>,
#  <h3 class="media-heading">
# ...

# %%
headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df11 = pd.DataFrame({'headline_news':headline_news})
df11
# Out:
#                                        headline_news
# 0  Investor Sentiment Uncertain, Yet Bitcoin’s HO...
# 1  Dogecoin (DOGE) is Currently the Most-Profitab...
# 2  US Inflation Numbers as Expected, Bitcoin Regi...
# 3  Ethereum Layer 2 Networks Set New Record with ...
# 4  Bitcoin Price Analysis: Is $64K Next for BTC o...
# 5  Ethereum Price Analysis: ETH Facing Key Resist...
# 6  Bitcoin Price Eyes $61K After Promising PPI Nu...
# 7  Important Ripple (XRP) Partnership With a Japa...
# 8  DEX Activity Surges as Retail Investors Seek E...
# 9  Here’s How Much BTC Metaplanet Has After The L...

# %% [markdown]
# * DF11 yet to be concat

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/10/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 10 of 2266 | CryptoPotato</title>
# [<h3 class="media-heading">
#  <a href="https://cryptopotato.com/coinbase-blasts-secs-arbitrary-approach-to-dex-compliance/">Coinbase Blasts SEC’s Arbitrary Approach to DEX Compliance</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/bitgo-moves-2-billion-of-mt-gox-bitcoin/">BitGo Moves $2 Billion Of Mt. Gox Bitcoin</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/three-arrows-capital-liquidators-sue-terraform-labs-for-1-3-billion-report/">Three Arrows Capital Liquidators Sue TerraForm Labs for $1.3 Billion: Report</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/liquidity-crisis-causes-major-price-slippages-during-cryptocurrency-sell-offs-kaiko/">Liquidity Crisis Causes Major Price Slippages During Cryptocurrency Sell-Offs: Kaiko</a>
#  </h3>,
#  <h3 class="media-heading">
# ...

# %%
headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df11 = pd.DataFrame({'headline_news':headline_news})
df11
# Out:
#                                        headline_news
# 0  Coinbase Blasts SEC’s Arbitrary Approach to DE...
# 1          BitGo Moves $2 Billion Of Mt. Gox Bitcoin
# 2  Three Arrows Capital Liquidators Sue TerraForm...
# 3  Liquidity Crisis Causes Major Price Slippages ...
# 4  Shiba Inu (SHIB) Team Issues a Critical Warnin...
# 5      Ripple (XRP) Blasts Through a Major Milestone
# 6  New Bitcoin Investors Are in Severe Stress, Ac...
# 7  Here’s When Altcoin Season Will Occur, Accordi...
# 8  Grayscale Ethereum Trust Records Zero Outflows...
# 9  Garbled Circuits 101: What Could They Enable f...

# %% [markdown]
# * DF11 yet to be concat

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/11/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 11 of 2266 | CryptoPotato</title>
# [<h3 class="media-heading">
#  <a href="https://cryptopotato.com/spot-bitcoin-etfs-on-track-to-pass-satoshi-in-btc-held-as-flows-flip-positive/">Spot Bitcoin ETFs on Track to Pass Satoshi in BTC Held as Flows Flip Positive</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/ripple-faces-key-resistance-at-0-63-will-this-consolidation-lead-to-xrp-price-breakout/">Ripple Faces Key Resistance at $0.63, Will This Consolidation Lead to XRP Price Breakout?</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/btc-price-fails-to-reclaim-60k-wif-dumps-5-daily-market-watch/">BTC Price Fails to Reclaim $60K, WIF Dumps 5% Daily (Market Watch)</a>
#  </h3>,
#  <h3 class="media-heading">
# ...

# %%
headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df12 = pd.DataFrame({'headline_news':headline_news})
df12
# Out:
#                                        headline_news
# 0  Spot Bitcoin ETFs on Track to Pass Satoshi in ...
# 1  Ripple Faces Key Resistance at $0.63, Will Thi...
# 2  BTC Price Fails to Reclaim $60K, WIF Dumps 5% ...
# 3  Top Ripple (XRP) Price Predictions, Important ...
# 4  SUI Price Prediction: Following the Two-Month ...
# 5  Elon Musk Claims Massive DDOS Attack Targeting...
# 6  Here’s What Tether’s CEO Revealed About the Co...
# 7  Ethereum Leads Market Recovery with $155M Infl...
# 8  BitGo’s Partnership with BiT Global Causes Con...
# 9  Futures Market Data Suggests Ethereum (ETH) Co...

# %% [markdown]
# * DF12 yet to be concat

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/12/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 12 of 2266 | CryptoPotato</title>
# [<h3 class="media-heading">
#  <a href="https://cryptopotato.com/why-is-the-ripple-xrp-price-up-today-14/">Why is the Ripple (XRP) Price Up Today?</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/important-binance-announcement-concerning-these-6-altcoins/">Important Binance Announcement Concerning These 6 Altcoins</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/marathon-digital-eyes-bitcoin-acquisition-with-250m-convertible-notes-offering/">Marathon Digital Eyes Bitcoin Acquisition with $250M Convertible Notes Offering</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/ethereum-base-fee-collapse-causes-eth-burn-to-fall-drastically/">Ethereum Base Fee Collapse Causes ETH Burn to Fall Drastically</a>
#  </h3>,
#  <h3 class="media-heading">
# ...

# %%
headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df13 = pd.DataFrame({'headline_news':headline_news})
df13
# Out:
#                                        headline_news
# 0            Why is the Ripple (XRP) Price Up Today?
# 1  Important Binance Announcement Concerning Thes...
# 2  Marathon Digital Eyes Bitcoin Acquisition with...
# 3  Ethereum Base Fee Collapse Causes ETH Burn to ...
# 4  Ripple Price Predictions: Is XRP on the Verge ...
# 5  Here Are Today’s Biggest Losers as Bitcoin (BT...
# 6  3 Big Things to Watch For in The Week Ahead in...
# 7  Bitcoin Retreats Below $60K as Liquidity Heatm...
# 8  Bitcoin Mining Firm Bitfarms Faces $27 Million...
# 9  Crypto Trading Volume Up 19% in July After Fou...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/13/')
print(type(request))
soup =BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 13 of 2266 | CryptoPotato</title>
# [<h3 class="media-heading">
#  <a href="https://cryptopotato.com/these-are-the-leading-cryptocurrencies-with-the-most-profitable-holders-details/">These Are the Leading Cryptocurrencies With the Most Profitable Holders: Details</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/binance-labs-boosts-solana-restaking-ecosystem-with-solayer-investment/">Binance Labs Boosts Solana Restaking Ecosystem with Solayer Investment</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/bitcoin-price-analysis-is-btc-in-danger-of-another-drop-to-50k/">Bitcoin Price Analysis: Is BTC in Danger of Another Drop to $50K</a>
#  </h3>,
#  <h3 class="media-heading">
# ...

# %%
headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df14 = pd.DataFrame({'headline_news':headline_news})
df14
# Out:
#                                        headline_news
# 0  These Are the Leading Cryptocurrencies With th...
# 1  Binance Labs Boosts Solana Restaking Ecosystem...
# 2  Bitcoin Price Analysis: Is BTC in Danger of An...
# 3  Ethereum Price Analysis: Is the Worst Over for...
# 4  Cardano (ADA) and Ethereum (ETH) Find Spot in ...
# 5  Binance Secured Over $73M in Stolen Funds from...
# 6  Dogecoin (DOGE) Jumps 5% Daily, Bitcoin (BTC) ...
# 7  Ripple (XRP) Inks a Strategic Deal in the Midd...
# 8  CoinShares Reveals Strong Financial Results fo...
# 9  Weekly ETF Recap: Here’s What Kind of Action t...

# %% [markdown]
# * df14 yet to be concat

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/14/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 14 of 2266 | CryptoPotato</title>
# [<h3 class="media-heading">
#  <a href="https://cryptopotato.com/heres-how-many-btc-addresses-are-rich-by-charlie-mungers-definition/">Here’s How Many BTC Addresses Are ‘Rich’ By Charlie Munger’s Definition</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/ceo-paolo-ardoino-responds-to-celsiuss-lawsuit-against-tether-calls-it-baseless-shakedown/">CEO Paolo Ardoino Responds to Celsius’s Lawsuit Against Tether, Calls it ‘Baseless Shakedown’</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/ripple-price-analysis-heres-what-you-need-to-know-about-xrps-next-move/">Ripple Price Analysis: Here’s What You Need to Know About XRP’s Next Move</a>
#  </h3>,
#  <h3 class="media-heading">
# ...

# %%
headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df15 = pd.DataFrame({'headline_news':headline_news})
df15
# Out:
#                                        headline_news
# 0  Here’s How Many BTC Addresses Are ‘Rich’ By Ch...
# 1  CEO Paolo Ardoino Responds to Celsius’s Lawsui...
# 2  Ripple Price Analysis: Here’s What You Need to...
# 3  What’s the Best Performing Cryptocurrency Sect...
# 4  These Metrics Suggest Bitcoin Faces Risk of Fu...
# 5  4 Long-Term Bull Market Signals for Ripple Lab...
# 6  Is XRP ATH Possible Following the Latest Rippl...
# 7  Bitcoin Dominance Skyrockets to 3-Year High as...
# 8  CFTC Awards Over $1M to Whistleblower for Impo...
# 9  Donald Trump Jr. Sets Sights on Banking Reform...

# %% [markdown]
# * df15 yet to be concat

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/15/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 15 of 2266 | CryptoPotato</title>
# [<h3 class="media-heading">
#  <a href="https://cryptopotato.com/usdt-issuer-tether-to-expand-workforce-to-200-employees-by-mid-2025/">USDT Issuer Tether to Expand Workforce to 200 Employees by Mid-2025</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/massive-bitcoin-and-crypto-crash-and-epic-recovery-this-weeks-recap/">Massive Bitcoin and Crypto Crash and Epic Recovery: This Week’s Recap</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/crypto-leaders-call-out-white-house-for-claiming-chokepoint-2-0-isnt-real/">Crypto Leaders Call Out White House For Claiming ‘Chokepoint 2.0’ Isn’t Real</a>
#  </h3>,
#  <h3 class="media-heading">
# ...

# %%
headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df16 = pd.DataFrame({'headline_news':headline_news})
df16
# Out:
#                                        headline_news
# 0  USDT Issuer Tether to Expand Workforce to 200 ...
# 1  Massive Bitcoin and Crypto Crash and Epic Reco...
# 2  Crypto Leaders Call Out White House For Claimi...
# 3  Unlucky Trader Lost Almost $1 Million After De...
# 4                  Important Shiba Inu (SHIB) Update
# 5  OKX to Deactivate Accounts Linked to Sanctione...
# 6  Bitcoin Could Hit Record High If This Happens ...
# 7  Ethereum Price Analysis: Is Another Correction...
# 8  Bitcoin Price Analysis: Are BTC Bulls Really B...
# 9  Crypto Price Analysis August-09: ETH, XRP, ADA...

# %% [markdown]
# * DF16 yet to be concat

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/16/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 16 of 2266 | CryptoPotato</title>
# [<h3 class="media-heading">
#  <a href="https://cryptopotato.com/best-defi-projects/">Top 14 Best Decentralized Finance (DeFi) Projects in 2024</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/ethereum-eth-explodes-10-daily-bitcoin-btc-jumps-above-60k-market-watch/">Ethereum (ETH) Explodes 10% Daily, Bitcoin (BTC) Jumps Above $60K (Market Watch)</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/shiba-inu-burn-rate-explodes-by-140000-as-the-shib-price-rebounds/">Shiba Inu Burn Rate Explodes by 140,000% as the SHIB Price Rebounds</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/can-2-5b-crypto-options-expiry-boost-market-momentum/">Can $2.5B Crypto Options Expiry Boost Market Momentum? </a>
#  </h3>,
#  <h3 class="media-heading">
# ...

# %%
headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df17 = pd.DataFrame({'headline_news':headline_news})
df17
# Out:
#                                        headline_news
# 0  Top 14 Best Decentralized Finance (DeFi) Proje...
# 1  Ethereum (ETH) Explodes 10% Daily, Bitcoin (BT...
# 2  Shiba Inu Burn Rate Explodes by 140,000% as th...
# 3  Can $2.5B Crypto Options Expiry Boost Market M...
# 4  This Popular Altcoin Soars 10% Daily Following...
# 5  Is the Ripple v SEC Legal Case Finally Over or...
# 6  Bitcoin Soared to Almost $63,000 Following Dea...
# 7  Metaplanet Obtains $6.8M Loan to Boost Bitcoin...
# 8  Harris Campaign Targets Crypto Voters with New...
# 9  Bitcoin Soars Back Beyond $59k Triggering $185...

# %% [markdown]
# * df17 yet to be concat

# %%
news_df = pd.concat([news_df,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17],
                   axis = 0)
news_df
# Out:
#                                         headline_news
# 0                                  Latest Crypto News
# 1   Self-custodial Bitcoin staking protocol Babylo...
# 2   AC Milan inks new sponsorship deal with crypto...
# 3   Bitwise expands into Europe with acquisition o...
# 4   Binance to support Frontier (FRONT) token swap...
# ..                                                ...
# 5   Is the Ripple v SEC Legal Case Finally Over or...
# 6   Bitcoin Soared to Almost $63,000 Following Dea...
# 7   Metaplanet Obtains $6.8M Loan to Boost Bitcoin...
# 8   Harris Campaign Targets Crypto Voters with New...
# 9   Bitcoin Soars Back Beyond $59k Triggering $185...
#
# [307 rows x 1 columns]

# %%
news_df = news_df.reset_index(drop = True)
news_df
# Out:
#                                          headline_news
# 0                                   Latest Crypto News
# 1    Self-custodial Bitcoin staking protocol Babylo...
# 2    AC Milan inks new sponsorship deal with crypto...
# 3    Bitwise expands into Europe with acquisition o...
# 4    Binance to support Frontier (FRONT) token swap...
# ..                                                 ...
# 302  Is the Ripple v SEC Legal Case Finally Over or...
# 303  Bitcoin Soared to Almost $63,000 Following Dea...
# 304  Metaplanet Obtains $6.8M Loan to Boost Bitcoin...
# 305  Harris Campaign Targets Crypto Voters with New...
# 306  Bitcoin Soars Back Beyond $59k Triggering $185...
#
# [307 rows x 1 columns]

# %%
news_df[news_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
news_df.dropna()
# Out:
#                                          headline_news
# 0                                   Latest Crypto News
# 1    Self-custodial Bitcoin staking protocol Babylo...
# 2    AC Milan inks new sponsorship deal with crypto...
# 3    Bitwise expands into Europe with acquisition o...
# 4    Binance to support Frontier (FRONT) token swap...
# ..                                                 ...
# 302  Is the Ripple v SEC Legal Case Finally Over or...
# 303  Bitcoin Soared to Almost $63,000 Following Dea...
# 304  Metaplanet Obtains $6.8M Loan to Boost Bitcoin...
# 305  Harris Campaign Targets Crypto Voters with New...
# 306  Bitcoin Soars Back Beyond $59k Triggering $185...
#
# [307 rows x 1 columns]

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/17/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 17 of 2266 | CryptoPotato</title>
# [<h3 class="media-heading">
#  <a href="https://cryptopotato.com/solana-based-etf-approved-in-this-country-report/">Solana-Based ETF Approved in This Country: Report</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/bitcoin-forms-bullish-ascending-flag-pattern-predicting-potential-breakout/">Bitcoin Forms Bullish Ascending Flag Pattern, Predicting Potential Breakout</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/xrp-whale-holdings-hit-all-time-high-amid-ripple-v-sec-lawsuit-update/">XRP Whale Holdings Hit All-Time High Amid Ripple v SEC Lawsuit Update</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/microstrategy-mstr-shares-are-now-90-cheaper-heres-why/">MicroStrategy (MSTR) Shares Are Now 90% Cheaper – Here’s Why</a>
#  </h3>,
#  <h3 class="media-heading">
# ...

# %%
headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df18 = pd.DataFrame({'headline_news':headline_news})
df18
# Out:
#                                        headline_news
# 0  Solana-Based ETF Approved in This Country: Report
# 1  Bitcoin Forms Bullish Ascending Flag Pattern, ...
# 2  XRP Whale Holdings Hit All-Time High Amid Ripp...
# 3  MicroStrategy (MSTR) Shares Are Now 90% Cheape...
# 4  New York Judge Approves $12.7 Billion Settleme...
# 5  COTI V2 Underway, Garbled Circuits Integration...
# 6  How High Can Ripple’s (XRP) Price Go After the...
# 7  Ripple (XRP) Skyrockets by Double Digits, Bitc...
# 8  Shiba Inu’s Price Probably Won’t 100x: But Thi...
# 9  Crypto Dip Buying Continues as Binance Sees $2...

# %% [markdown]
# * df18 uncat

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/18/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 18 of 2266 | CryptoPotato</title>
# [<h3 class="media-heading">
#  <a href="https://cryptopotato.com/bitcoins-20k-drawdown-in-august-leaves-short-term-holders-reeling/">Bitcoin’s $20K Drawdown in August Leaves Short-Term Holders Reeling</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/ark-invest-loads-up-on-coinbase-stock-amid-market-dump/">Ark Invest Loads up on Coinbase Stock Amid Market Dump</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/ripple-fined-125m-in-lawsuit-against-sec-xrp-price-soars-20-immediately/">Ripple Fined $125M in Lawsuit Against SEC, XRP Price Soars 20% Immediately</a>
#  </h3>,
#  <h3 class="media-heading">
#  <a href="https://cryptopotato.com/nexera-protocol-hacked-for-1-5-million-nxra-token-drops-over-40/">Nexera Protocol Hacked for $1.5 Million, NXRA Token Drops Over 40%</a>
#  </h3>,
#  <h3 class="media-heading">
# ...

# %%
headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df19 = pd.DataFrame({'headline_news':headline_news})
df19
# Out:
#                                        headline_news
# 0  Bitcoin’s $20K Drawdown in August Leaves Short...
# 1  Ark Invest Loads up on Coinbase Stock Amid Mar...
# 2  Ripple Fined $125M in Lawsuit Against SEC, XRP...
# 3  Nexera Protocol Hacked for $1.5 Million, NXRA ...
# 4  Three Comma Club: Michael Saylor Says He Perso...
# 5  Bitcoin Wallet From Satoshi Era Awakens After ...
# 6  Bitcoin Whales Accumulated $22.8 Billion in BT...
# 7  This Is How SHIB Started: Neiro Pumps After Bu...
# 8  What is RWA in Crypto: Top 10 Real-World Asset...
# 9  Bitcoin Could Hit New All-Time High if It Stay...

# %% [markdown]
# * df19 uncat

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/19/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df20 = pd.DataFrame({'headline_news':headline_news})
df20
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 19 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0           Why is the Cardano (ADA) Price Up Today?
# 1  Here’s How Much Ripple (XRP) and Shiba Inu (SH...
# 2  Ripple Price Analysis: XRP Bulls Reclaim $0.5 ...
# 3  Bitcoin Price Analysis: 2 Targets for BTC Foll...
# 4  Important Ripple (XRP) Metric Hits a Three-Mon...
# 5  WIF Skyrockets 27% Daily After Meme Coin Massa...
# 6  Crypto Market Cycle Indicator Shows Bear Signs...
# 7  These Shiba Inu Indicators Skyrocket as the SH...
# 8  No Demand? BlackRock’s ETH Fund Enters Top 6 E...
# 9  This European Hedge Fund Giant Announces $464 ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/20/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df21 = pd.DataFrame({'headline_news':headline_news})
df21
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 20 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  SEC Requests Court to Deny Coinbase’s ‘Broad’ ...
# 1  Bitcoin’s Correlation With TradFi Markets is I...
# 2  Semler Scientific Boosts Bitcoin Treasury Hold...
# 3  Bitcoin ETFs Reached 4-Month High in Daily Tra...
# 4  AI is Going to be the Center of our Lives, Lik...
# 5  Ronin Network Falls Victim to Another Exploit,...
# 6  Important Ripple (XRP) Announcement Concerning...
# 7  Crypto Crash: Is Now A Good Time To Buy Bitcoi...
# 8  Analysts Eye Recovery as Crypto Markets Bounce...
# 9  Ripple (XRP) Jumps 15% Amid Overall Market Rec...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/21/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df22 = pd.DataFrame({'headline_news':headline_news})
df22
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 21 of 2188 | CryptoPotato</title>
#                                        headline_news
# 0  Ripple (XRP) v. SEC Lawsuit Update June 14th: ...
# 1  Upcoming Opportunities in the Crypto Market: W...
# 2  Trezor Releases New Safe 5 Hardware Wallet (Bi...
# 3  Bitcoin Struggles at $67K as Polkadot (DOT) Te...
# 4  How to Make Money With Meme Coins? Novogratz C...
# 5  Coinbase Announces Support for This Trending M...
# 6  Andrew Tate and Iggy Azalea Accused of Insider...
# 7  This Popular Meme Coin Receives Further Suppor...
# 8  Paxos Reportedly Downsizes Workforce by 20%: D...
# 9  UwU Lend Protocol Hit by Another $3.7 Million ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/22/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df23 = pd.DataFrame({'headline_news':headline_news})
df23
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/23/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df24 = pd.DataFrame({'headline_news':headline_news})
df24
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 23 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Over $500 Billion Gone From Crypto Markets Sin...
# 1  Meme Coin Massacre: DOGE, SHIB, WIF, and More ...
# 2  Someone is Buying the Ethereum (ETH) Dip… But ...
# 3  Justin Sun Dispells Rumors of Bitcoin Liquidat...
# 4  Ripple (XRP) Price Collapses by 17% Daily: Whe...
# 5  Ethereum Prices Dump 23% in Massive Market Plu...
# 6  The Reason Behind Bitcoin’s Price Crash: Arthu...
# 7  To Lose $17,000 in a Week: Bitcoin Plunges to ...
# 8  New Research Model Sheds Light on Cryptocurren...
# 9  April’s Bitcoin Halving Drives Riot Platforms’...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/24/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df25 = pd.DataFrame({'headline_news':headline_news})
df25
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 24 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Ripple Price Analysis: Here’s Why XRP is Plung...
# 1  Crypto Hacks Surge in July 2024, PeckShield Re...
# 2  Bitcoin (BTC) Suddenly Plummets to $57K, Leavi...
# 3  Stablecoin Market Cap Hits $164B, Extending 10...
# 4  3 Possible Reasons Behind Bitcoin’s $10,000 We...
# 5  Altcoins Bleed Out Heavily as Bitcoin (BTC) Sl...
# 6  How Low Can Bitcoin Go After Slipping Below $6...
# 7  Can Bitcoin (BTC) Hit $100,000 if the Russia-U...
# 8  California DMV Digitizes 42 Million Car Titles...
# 9  BitClout Founder Al-Naji Faces Charges Over $2...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/25/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df26 = pd.DataFrame({'headline_news':headline_news})
df26
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 25 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  $530K Stolen: ZachXBT Links Convicted Hacker’s...
# 1  Bitcoin Price Analysis: Following a 10% Weekly...
# 2  This is Why Bitcoin Could See Less Selling Pre...
# 3  Ethereum Price Analysis: ETH Plunges Below $3K...
# 4  Crypto Markets Shed $150 Billion in 2 Days as ...
# 5  ChatGPT Analyzes the Effect on Bitcoin’s Price...
# 6  Bitcoin, Ethereum ETF Weekly Recap: Substantia...
# 7  Bitfarms’ Operational Hash Rate Hits 11.1 EH/s...
# 8  Marathon Digital Falls Short of Revenue Predic...
# 9  MicroStrategy to Raise $2 Billion via Class A ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/26/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df27 = pd.DataFrame({'headline_news':headline_news})
df27
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 26 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Important Cardano Update Related to the Networ...
# 1  Coinbase Q2 Revenue Hits $1.45B, Net Income Dr...
# 2  Bitcoin Follows Wall Street Crash by Tumbling ...
# 3  Hong Kong’s Largest Online Broker Now Offers B...
# 4  Here’s When Morgan Stanley’s Wealthy Clients W...
# 5  Crypto Markets Turn Red Despite BoE’s Interest...
# 6  MicroStrategy Adds 169 BTC to Holdings, Unveil...
# 7  Ripple (XRP) Price Plunges by 14% in 3 Days: M...
# 8  Insider Trading Scandal Hits NEIRO on Ethereum...
# 9  BTC Recovers From a Dip to $62K, XRP’s Decline...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/27/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df28 = pd.DataFrame({'headline_news':headline_news})
df28
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 27 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Crypto Price Analysis August-02: ETH, XRP, ADA...
# 1  Shiba Inu (SHIB) Price Collapse: Here’s How Ma...
# 2  Can Crypto Markets Recover When $2.4B Bitcoin ...
# 3   These Key Metrics Are Driving DeFi to 2022 Highs
# 4  New Bitcoin Act Legislation Aims to Establish ...
# 5  South Korea Defeats United States In Do Kwon E...
# 6  Important Ripple (XRP) Announcement: Real Worl...
# 7        Tether Rakes in $5.2B in Profit for H1 2024
# 8  Bitwise CIO Hougan Says the Bitcoin Market ‘Is...
# 9  Bitcoin Price Analysis: BTC Dips Below $64K Bu...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/28/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df29 = pd.DataFrame({'headline_news':headline_news})
df29
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 28 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Bank of England Follows Europe and Canada by C...
# 1  Ripple Price Analysis: The Reason XRP Crashed ...
# 2  Top Meme Coins to Put on Your Watch List in Au...
# 3  Ether Price Dumps Almost 4% as Spot Ethereum E...
# 4  XRP and SOL Retrace Hard, While BTC Price Drop...
# 5  Shiba Inu (SHIB) Sees 60% Monthly Drop in Burn...
# 6  Significant Drop in Meme Coin Activity and Pri...
# 7  Over $220 Million in Liquidations as Bitcoin (...
# 8  Here’s Why Matrixport Recommends Bitcoin for I...
# 9  ZKX Token Plummets as Crypto.com-Backed DEX Sh...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/29/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df30 = pd.DataFrame({'headline_news':headline_news})
df30
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 29 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Bitcoin Leaves Exchanges in Droves as Daily Ne...
# 1  Strong Accumulation Demand for XRP as Ripple P...
# 2  Grayscale Launches Mini Spot Bitcoin ETF at ‘U...
# 3  Ripple (XRP) and Solana (SOL) are Among the To...
# 4  Why is the Shiba Inu (SHIB) Price Down This Week?
# 5  Goldman Sachs CEO Predicts Bitcoin Could Rival...
# 6  Mt. Gox Transfers $2.2 Billion in BTC to New A...
# 7  Important Binance Update Concerning Cardano (A...
# 8  Ripple (XRP) Defies Market Sentiment With 8% S...
# 9            Why Is the Ripple (XRP) Price Up Today?

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/30/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df31 = pd.DataFrame({'headline_news':headline_news})
df31
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 30 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Analysts Eye September for Potential Bitcoin B...
# 1  Russia Moves to Legalize Cryptocurrency Paymen...
# 2  BlackRock Solana ETF Not Happening Anytime Soo...
# 3  21Shares Integrates Chainlink Proof of Reserve...
# 4  Crypto Now Boasts Top Super PAC In U.S. Electi...
# 5  SEC Plans to Amend Binance Complaint, Avoiding...
# 6  WisdomTree CEO Lists 3 Reasons Why Bitcoin Wil...
# 7  Bitcoin Price Analysis: How Deep Can This Corr...
# 8  Ethereum Price Analysis: ETH Drops to $3.3K bu...
# 9  Key Shiba Inu Metrics Skyrocket Today: SHIB Pr...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/31/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df32 = pd.DataFrame({'headline_news':headline_news})
df32
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 31 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Solana (SOL) Surpasses Ethereum (ETH) in These...
# 1  This is Why Bitcoin May Pull Further Back, Acc...
# 2  Ripple (XRP) Soars by 5% Hourly Despite the Ov...
# 3  Historic Ripple (XRP) Price Pattern Signals a ...
# 4  Crypto Markets Shed $100B Daily as Bitcoin (BT...
# 5  Political Polls and Government Moves: What’s B...
# 6  US National Debt Hits Record $35 Trillion, Can...
# 7  Known Bitcoin Holder Abducted and Murdered Ove...
# 8  Beware of Scams: BlackRock Confirms No Social ...
# 9  Cantor Fitzgerald Announces $2 Billion Bitcoin...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/32/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df33 = pd.DataFrame({'headline_news':headline_news})
df33
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 32 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Spot Ethereum ETFs Boost Trading Volumes to $1...
# 1  Bitcoin Plummets Under $67,000 As U.S. Governm...
# 2  Bitcoin Bounces Back Near ATH: The Forces Behi...
# 3  Justin Sun Calls for China to Reevaluate Crypt...
# 4  One Billion XRP Unlock Incoming and What it Me...
# 5  Solana (SOL) Flips Binance Coin (BNB) to Becom...
# 6  9 Best Ethereum (ETH) ETFs in 2024: Full Compa...
# 7  Ethereum Open Interest Rises $1.5B in 3 Weeks,...
# 8  Ripple Price Analysis: Is XRP on the Verge of ...
# 9  What’s Next for Ripple’s Price? 3 XRP Charts t...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/33/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df34 = pd.DataFrame({'headline_news':headline_news})
df34
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 33 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Hong Kong Joins Bitcoin Reserve Debate, Legisl...
# 1  Shiba Inu (SHIB) Blasts Through Another Milest...
# 2  Bitcoin Taps 7-Week Peak Close to $70K, Bitcoi...
# 3  Five Things That Could Move Crypto Markets Thi...
# 4  Senator Lummis Proposes $67B Strategic Bitcoin...
# 5  This Popular Analyst Remains a Dogecoin (DOGE)...
# 6  Interpol Issues Red Notice for Hong Kong Crypt...
# 7  Nansen Says Bitcoin Investors Should Become Ri...
# 8  Riot Platforms Acquires Block Mining for $92.5...
# 9  Diamond Hand Trader Pocketed Over $1.7 Million...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/34/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df35 = pd.DataFrame({'headline_news':headline_news})
df35
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 34 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Top 10 NFT-Related Cryptocurrencies by Develop...
# 1  Spot ETF Inflows to Have Weaker Effect on Ethe...
# 2  ChatGPT Analyzes the Impact on Bitcoin’s Price...
# 3  BTC Price Faced Massive Volatility Amid Trump ...
# 4  Ferrari Expands to Europe with Cryptocurrency ...
# 5  Europol Claims That Bitcoin Remains Top Choice...
# 6  Bitcoin Dumped $2.5K Before Recovery: Trump’s ...
# 7  Donald Trump Says Bitcoin Will Likely Overtake...
# 8  Ethereum Price Analysis: Will ETH Charge Towar...
# 9  Russian-Speaking Groups Dominate Crypto-Relate...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/35/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df36 = pd.DataFrame({'headline_news':headline_news})
df36
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 35 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0   Ethereum ETFs Are Not Like Bitcoin ETFs (So Far)
# 1  Here’s The Aftermath After the First Trading D...
# 2     Top Bitcoin (BTC) Price Predictions as of Late
# 3  Ripple (XRP) and Shiba Inu (SHIB) are Among th...
# 4  Bitcoin Price Eyes $68K Again, Solana Soars to...
# 5  Here’s Why VanEck’s CEO Holds ‘Way Over 30%’ o...
# 6  Important Ripple (XRP) Price Predictions: Bull...
# 7  RFK Jr. Proposes Massive Bitcoin Buy: Match US...
# 8  The State Of Michigan Has Bought Bitcoin In It...
# 9  US Senator Elizabeth Warren Criticizes Foreign...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/36/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df37 = pd.DataFrame({'headline_news':headline_news})
df37
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 36 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Jersey City Pension Fund to Invest in Bitcoin ...
# 1  Ethereum Foundation Wallet Transfers Over $290...
# 2  Here’s Why Bitcoin’s Net Flows to Exchanges Ha...
# 3  bitFlyer Acquires FTX Japan to Expand Crypto C...
# 4  Ripple and Solana Steal the Show as Ethereum E...
# 5  Meme Tokens Surge Past Bitcoin in Turkish Trad...
# 6  Security Matters: How’s Zircuit Planning to Mi...
# 7  Ripple Price Analysis: Is XRP Ready to Finally...
# 8  Bitcoin Price Analysis: Here’s Why BTC Jumped ...
# 9  Crypto Price Analysis July-26: ETH, XRP, ADA, ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/37/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df38 = pd.DataFrame({'headline_news':headline_news})
df38
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/38/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df39 = pd.DataFrame({'headline_news':headline_news})
df39
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 38 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  One in a Billion: Tiny Bitcoin Mining Device D...
# 1  VanEck Predicts Bitcoin Could Reach $2.9 Milli...
# 2  Ripple (XRP) Community Speculates on Upcoming ...
# 3  Crypto Markets Lost $100B Overnight as BTC, ET...
# 4  Ripple (XRP) Price Outlook: Can Bulls Defend $...
# 5  ETH Price Dumped 10% as Spot Ethereum ETFs Saw...
# 6  Kamala Harris Will Not Attend the Bitcoin Conf...
# 7  No Forks Required: BitcoinOS Verifies First ZK...
# 8  Bitcoin Banking App Fold Will Soon Trade On Th...
# 9  Senator Cynthia Lummis Criticizes Biden Admini...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/39/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df40 = pd.DataFrame({'headline_news':headline_news})
df40
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 39 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Biden’s Exit and Harris’s Rise Could Mean Shor...
# 1  Important Binance Announcement Concerning Nume...
# 2  Are Mt. Gox Creditors HODLing The Newly-Receiv...
# 3  Ethereum Holders Accumulate 113K ETH, Outpacin...
# 4  Demand-Supply Power Tussle: Analyst Sees 3 Bul...
# 5  Ethereum Price Analysis: Bullish Breakout Towa...
# 6  Bitcoin Price Analysis: The Bulls Must Protect...
# 7  Here’s How Much Crypto Sanctioned Russian Medi...
# 8  Ethereum Price Predictions: New ATH in the Nea...
# 9  Mt. Gox Bitcoin Movements Continue, Trustee Tr...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/40/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df41 = pd.DataFrame({'headline_news':headline_news})
df41
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 40 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Bad News for Shiba Inu Bulls? Here’s Why SHIB’...
# 1  BTC Price Retraces to $66K as Spot Bitcoin ETF...
# 2  Spot Ethereum ETFs $100M Debut: BlackRock Lead...
# 3  Base Layer 2 Activity Doubles Competitors with...
# 4  US Government Transfers Nearly $4M Worth of Se...
# 5  India Maintains High Crypto Tax Rate Despite I...
# 6  Bitcoin Miners Return to Profitability as BTC ...
# 7  Will Bitcoin’s (BTC) Price Crash if Kamala Har...
# 8  Coinbase Premium Turns Positive in Early July:...
# 9  ETH Price Slips Below $3.5K as Spot Ethereum E...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/41/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df42 = pd.DataFrame({'headline_news':headline_news})
df42
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 41 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  We Asked ChatGPT if Ripple (XRP) Can Hit an AT...
# 1  Best Hardware Wallets 2024: Top 5 Crypto Cold ...
# 2  Spot Ethereum ETF Launch: Investors Brace for ...
# 3  Ripple (XRP) Dominates Ethereum (ETH) on This ...
# 4  Robert Kiyosaki Says Bitcoin Will Hit $105K Ne...
# 5  Ripple (XRP) Price Outlook: Bulls Attempt to C...
# 6  Bitcoin (BTC) Price Eyes $67K Again as Most Al...
# 7  BlackRock’s Bitcoin ETF Leads $534M Inflow Sur...
# 8  Shiba Inu (SHIB) Price Underperforms but Here ...
# 9  Analysts Forecast ETH Pullback Despite SEC’s O...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/42/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df43 = pd.DataFrame({'headline_news':headline_news})
df43
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 42 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Hong Kong to Introduce Asia’s First Bitcoin Fu...
# 1  Short Bitcoin ETFs Take a Hit With $1.9M in Ou...
# 2  What Are Ripple’s (XRP) Chances to Chart a New...
# 3  Here’s the Percentage of Bitcoin Addresses in ...
# 4  Bitcoin Price Analysis: BTC Bulls Eye $70K But...
# 5  These Meme Coins Explode by Double Digits: Are...
# 6  Ethereum Turns 10: A Decade of Blockchain Revo...
# 7  WazirX Increases White Hat Recovery Reward to ...
# 8  Is SHIB’s Price in Trouble as These Key Shiba ...
# 9  This Token Gained The Most After Biden’s Withd...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/43/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df44 = pd.DataFrame({'headline_news':headline_news})
df44
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 43 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Here’s How Much a Ripple (XRP) Investment From...
# 1  BTC Price Retraces After Hitting 6-Week High, ...
# 2             Ripple v. SEC Lawsuit Update July 22nd
# 3  Bitcoin Topped $68,000, What Has Driven The 17...
# 4  Six Things to Watch for Crypto Market Impact T...
# 5  Massive Meme Coin Volatility as Joe Biden Quit...
# 6  Kraken Becomes Official Crypto Partner of Tott...
# 7  Buying Bitcoin Paid Off for Metaplanet as Shar...
# 8  Bitcoin Dumped $2K in Minutes After President ...
# 9  6 Reasons XRP Price Could Hit $1 This Summer (...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/44/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df45 = pd.DataFrame({'headline_news':headline_news})
df45
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 44 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Bitcoin ETFs See $1.2B Inflow as CBOE Sets Eth...
# 1  Very Optimistic Bitcoin Price Prediction by Me...
# 2  Here Are This Week’s Best Performing Cryptocur...
# 3      Critical Warning by the Shiba Inu (SHIB) Team
# 4  Ripple Price Analysis: XRP Bulls Keen on Takin...
# 5  Bitcoin Price Analysis: Here’s the Next Target...
# 6  Businessman Scammed Out of $400K in Crypto, 3 ...
# 7  State Street Is Exploring a Stablecoin and Tok...
# 8  Kraken Institutional Debuts Custody Services i...
# 9  Bitcoin’s Price May Have Bottomed Out, But The...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/45/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df46 = pd.DataFrame({'headline_news':headline_news})
df46
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 45 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Which Dog-Themed Meme Coin Will Perform Best i...
# 1  Bitcoin Pokes Above $67K as Altcoins See Consi...
# 2  Crypto Trading Volume Declined for Third Conse...
# 3  Three Reasons Why the Bitcoin (BTC) Price Coul...
# 4  We Asked ChatGPT if Ripple (XRP) Can Become a ...
# 5  Bitzlato Founder Sentenced to Prison for Facil...
# 6  Trump and Bitcoin: How Institutional Bets on $...
# 7  Bybit Bitcoin and USDT Holdings Surge Accordin...
# 8  Bitcoin Rockets To $66,400, Triggering $131 Mi...
# 9  WazirX Taps Forensic Experts, Law Enforcement ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/46/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df47 = pd.DataFrame({'headline_news':headline_news})
df47
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 46 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Bitcoin Pushes $66K Following Donald Trump Ass...
# 1        Best DeFi Wallets for 2024: Top 13 Reviewed
# 2  Unpacking the WazirX Hack: What Happened and H...
# 3  Importan Ripple (XRP) Update: Certain Users Ne...
# 4  Trouble for Shiba Inu (SHIB)? Major Exchange A...
# 5  Crypto Price Analysis July-19: ETH, XRP, ADA, ...
# 6  Crypto Mixer Tornado Cash Experiences Resurgen...
# 7  Bitcoin Dips Below $64K as Altcoins Also Decli...
# 8          Why is the Ripple (XRP) Price Down Today?
# 9  Shiba Inu (SHIB) Price Crashes 7% Daily But Th...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/47/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df48 = pd.DataFrame({'headline_news':headline_news})
df48
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 47 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Here’s When Polygon Will Migrate from MATIC to...
# 1  Vitalik Buterin Urges Crypto Community to Look...
# 2  Bankrupt Crypto Lender BlockFi to Commence Rep...
# 3  DeFi Technologies (DEFTF) Buys Another $6 Mill...
# 4  Charles Hoskinson Warns: Biden Victory Equals ...
# 5  Spot Ethereum ETF Race Intensifies as Issuers ...
# 6  Ethereum Price Analysis: Is $3.7K Realistic fo...
# 7  Bitcoin Price Analysis: Here’s What it Will Ta...
# 8  BitGo Launches Support for Bitcoin L2 Stacks a...
# 9  Ripple v SEC Lawsuit Resolution Incoming? CEO ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/48/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df49 = pd.DataFrame({'headline_news':headline_news})
df49
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 48 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Why The Mt. Gox Impact on BTC Markets Is Overe...
# 1  Hackers Drain $235M From Indian Exchange Wazir...
# 2  This Declining Bitcoin Metric Could Actually S...
# 3  What’s Next for the SHIB Price? These Shiba In...
# 4  3 Factors to Consider for Ripple: Will the XRP...
# 5  Ripple, Shiba Inu Retrace Hard as Bitcoin Lose...
# 6  Big for Ripple’s Price? This XRP Metric Hits a...
# 7  OKX to Discontinue Services in Nigeria, Here’s...
# 8  Trump Set to Launch Fourth NFT Collection, Cit...
# 9  Silicon Valley Is In Love With Trump Because o...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/49/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df50 = pd.DataFrame({'headline_news':headline_news})
df50
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 49 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Arthur Hayes’ Maelstrom Launches Bitcoin Grant...
# 1  Big Binance Announcement for Shiba Inu (SHIB) ...
# 2  Grayscale Launches New Fund Targeting Decentra...
# 3  Here’s How ETH Could Surge Above $5,000 in 202...
# 4  Ripple Price Analysis: XRP Explodes Above $0.6...
# 5  Craig Wright Finally Admits That He Isn’t Sato...
# 6  Nansen’s New Dashboard Reveals Aptos’s Dramati...
# 7    Why is the Shiba Inu (SHIB) Price Up This Week?
# 8  Bullish Narratives Emerge as Ripple (XRP) Gain...
# 9  Ripple (XRP) Achieves a Massive Milestone Foll...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/51/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df51 = pd.DataFrame({'headline_news':headline_news})
df51
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/52/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df52 = pd.DataFrame({'headline_news':headline_news})
df52
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 52 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Bitcoin’s Weekend Recovery Doesn’t Mean the Do...
# 1  $60M Dormant Bitcoin Wallet Emerges After Near...
# 2  This Is The Latest Ethereum Layer 2 Protocol t...
# 3  Over $35M Laundered from DMM Bitcoin Hack Thro...
# 4  This Cat-Themed Meme Coin Enters Crypto’s Top ...
# 5  Mysterious Chainlink Whales Drive $167M LINK W...
# 6  Is Ripple (XRP) on the Verge of a Massive Bull...
# 7  BlackRock CEO Explains Why He’s No Longer A Bi...
# 8  BlackRock Hits Record $10.6 Trillion in Assets...
# 9  YTD Digital Asset Inflows Surge to $17.8B, Sha...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/53/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df53 = pd.DataFrame({'headline_news':headline_news})
df53
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 53 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Ethereum Price Analysis: ETH Eyes $3.5K as ETF...
# 1  Three Things That Could Influence Crypto Marke...
# 2  Ripple v SEC Lawsuit: One Year Anniversary Sin...
# 3  Bitcoin Surges to $63,000 as US Whales and Ins...
# 4  This Meme Coin Trader Pocketed $8 Million From...
# 5  Crypto Markets Add $200B in 4 Days as Bitcoin ...
# 6  Trump Will Speak at Bitcoin Conference Despite...
# 7  Ripple (XRP) Price Soars Almost 30% Weekly: ‘G...
# 8  Argentina Leads Key Crypto Adoption Metric in ...
# 9  Metaplanet Expands Bitcoin Holdings with $2.4 ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/54/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df54 = pd.DataFrame({'headline_news':headline_news})
df54
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 54 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Kraken and Spanish Football Club Atlético de M...
# 1  Bitcoin Soars Above $61K Causing Over $100 Mil...
# 2  This Hedge Fund Plans to Raise $500M for AI an...
# 3  Trump’s Crypto Pivot Wins Over 13% of Formerly...
# 4  Here’s How Crypto Voters Will Affect the Traje...
# 5  Bitcoin Price Analysis: BTC Bulls Back in Town...
# 6  Top Meme Coins to Put on Your Watch List in H2...
# 7  Ripple Price Analysis: XRP Explodes 20% Weekly...
# 8  Bitcoin ETF Inflows Hit 5-Week High as Spot Ma...
# 9  Bull or Bear Phase? CryptoQuant Says Bitcoin I...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/55/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df55 = pd.DataFrame({'headline_news':headline_news})
df55
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 55 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Top 10 RWA Cryptocurrencies by Development Act...
# 1  Ripple Finds a Spot in a Very Prestigious List...
# 2  BTC Price Taps $60K for the First Time in 9 Da...
# 3  Donald Trump-Related Crypto Tokens Surge as Fo...
# 4  Massive Volatility in Crypto Markets Amid Dona...
# 5  Global Crypto Trading Volume to Surpass $108 T...
# 6  Bitcoin Mining Contributing to Massive Electri...
# 7  Only Half of Crypto Investors Remain Bullish: ...
# 8  Bail Denied for Tornado Cash Dev Alexey Pertse...
# 9  The Possible Reasons Ripple (XRP) Exploded by ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/56/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df56 = pd.DataFrame({'headline_news':headline_news})
df56
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 56 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  What is DePIN? Top 10 DePIN Crypto Projects in...
# 1  Weekly Bitcoin Fees Fall to Lowest Level in 8 ...
# 2     Top Bitcoin (BTC) Price Predictions as of Late
# 3  Can XRP Flip ETH in the Event of a Ripple Vict...
# 4  Ripple (XRP) Explodes 10% Daily, Bitcoin (BTC)...
# 5  Tether (USDT) Loses Ground on Centralized Exch...
# 6  It’s Over: The German Government Has Run Out O...
# 7  House Fails to Overturn Biden’s Veto on Crypto...
# 8  Judge Criticizes Coinbase’s Attempt to Subpoen...
# 9  Reversal Ahead? Institutions Are Buying The Bi...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/57/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df57 = pd.DataFrame({'headline_news':headline_news})
df57
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 57 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Ethereum Price Analysis: Is ETH on the Verge o...
# 1  IREN Shares Plunge 24% on Nasdaq Following ‘Wi...
# 2  Bitcoin En Route to $60K Recovery, XRP Leads A...
# 3  Litecoin Surpassed Dogecoin in This Important ...
# 4  German Bitcoin Sell-Off Nears Completion, Here...
# 5  Bitcoin Price Analysis: Likelihood of a BTC Dr...
# 6  Crypto Price Analysis July-12: ETH, XRP, ADA, ...
# 7  Ripple v. SEC Lawsuit Resolution Speculations ...
# 8  Can Markets Recover as $2 Billion in Crypto Op...
# 9  Bitcoin Price Retraces After CPI Pump, BONK Du...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/58/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df58 = pd.DataFrame({'headline_news':headline_news})
df58
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 58 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Key Shiba Inu Metrics Plummet as SHIB Price He...
# 1  Railgun Blocks Inferno Drainer’s Attempt to La...
# 2  Donald Trump to Take Stage at Bitcoin Conferen...
# 3  MicroStrategy (MSTR) Pops 3% After Saylor Anno...
# 4  Shiba Inu (SHIB) ETF: The Pros and Cons Accord...
# 5  ARG Token Value Soars as Argentina Advances to...
# 6  SEC Drops Investigation Into Paxos For BUSD St...
# 7  Sell-Off by Small Bitcoin Traders Contrasted b...
# 8  Ripple Price Analysis: XRP Surges to $0.45 but...
# 9  Rising Sophistication in Crypto-Native Money L...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/59/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df59 = pd.DataFrame({'headline_news':headline_news})
df59
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 59 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Bitcoin Explodes Toward $60K as June CPI Numbe...
# 1  Historic XRP Price Pattern Suggests Major Ripp...
# 2  Elwood Technologies’ Large ETH Transfers Raise...
# 3  DeFi Pioneer Compound Finance Falls Victim to ...
# 4  BTC Falls Back to $58K After Failing to Challe...
# 5  Crypto Exchange BitMEX Pleads Guilty to Violat...
# 6                Ripple v SEC Lawsuit Update July 11
# 7  Here’s How Much Bitcoin (BTC) Drake Lost After...
# 8             Important Binance Update for July 17th
# 9  Illinois Court Confirms That Bitcoin And Ether...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/60/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df60 = pd.DataFrame({'headline_news':headline_news})
df60
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 60 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  CertiK Flags Nearly $1M Transfer to Tornado Ca...
# 1  Ethereum Hitting New Records: 47.36 Million ET...
# 2  Bitcoin Price Analysis: BTC Not Quite Ready to...
# 3  Elliptic Links Huione Guarantee to Global Mone...
# 4  Bitcoin (BTC) Price Prediction for the end of ...
# 5  Big Bank Crypto Move: Standard Chartered Subsi...
# 6  Bitcoin Bulls Eye $60K Next as Bittensor (TAO)...
# 7  Ripple (XRP) Finds a Spot on an Important List...
# 8  Bitcoin v. Ethereum: Why BTC is Dominating the...
# 9  Important Shiba Inu (SHIB) Metrics go Down Des...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/61/')
print(type(request))
soup =BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df61 = pd.DataFrame({'headline_news':headline_news})
df61
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 61 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Paxful Co-Founder Pleads Guilty to AML Program...
# 1  Deadline Speculations for a Solana ETF Ramp Up...
# 2  Australia’s ASX Welcomes Another Bitcoin ETF w...
# 3  Controversial Meme Coin Explodes by 150% Follo...
# 4  Spot Ethereum ETF Launch Anticipated on July 1...
# 5  Ethereum (ETH) Gearing up for a New ATH After ...
# 6  Back on Track: Spot Bitcoin ETFs Draw $295M on...
# 7  Circle’s USDC Emerges as Top Beneficiary of EU...
# 8  Why is Golem Moving Millions in ETH to Central...
# 9              MANTRA (OM) Price Prediction to Watch

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/62/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df62 = pd.DataFrame({'headline_news':headline_news})
df62
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 62 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Local Bottom or More Pain for Bitcoin’s Price?...
# 1  Why Bitcoin Could Still Fall to $47K in This M...
# 2  Bitcoin Solidifies at $57K While Solana (SOL) ...
# 3  Chainlink (LINK) Price Outlook: Whales Step up...
# 4    This Popular Meme Coin Soars 25% Daily: Details
# 5  Massive Ripple (XRP) Price Prediction, is it T...
# 6  Bitcoin Outlook for Q4 2024: Analyst Look at H...
# 7  Buy the Bitcoin Dip? Investors Seize Opportuni...
# 8  Republican Party Platform Vows To “End Crypto ...
# 9  The Latest Bitcoin Price Predictions After Las...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/63/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df63 = pd.DataFrame({'headline_news':headline_news})
df63
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 63 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  These Altcoins Plummet Following Delistings fr...
# 1  German Government Prepares To Sell Another $90...
# 2  Ripple Price Analysis: After the Plunge Toward...
# 3  Bitcoin Price Analysis: BTC Needs to Reclaim T...
# 4  Interesting Turn of Events: Popular Scammers L...
# 5  98% of Altcoins Have Peaked, Meme Coins Could ...
# 6  SHIB Price Explodes in Recovery but These Shib...
# 7  Shiba Inu (SHIB) Developments, Ripple (XRP) Pr...
# 8  Enhanced Bitcoin Price Volatility and Altcoins...
# 9  What’s in Store for Bitcoin This Week? 6 Thing...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/64/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df64 = pd.DataFrame({'headline_news':headline_news})
df64
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 64 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0               Ripple v SEC Lawsuit Update July 8th
# 1     Top Meme Coins Crash as Crypto Markets Decline
# 2  Interesting List: Top 10 Cryptocurrencies by 1...
# 3  Top RWA Cryptocurrencies to Put on Your Watchl...
# 4  What is the Key to Bitcoin’s Next Bull Rally? ...
# 5  Bitcoin (BTC) Price Predictions: Time for a Ne...
# 6  Critical Warrning for the Shiba Inu (SHIB) Com...
# 7  Bitcoin Climbs Above $57K as This Popular Meme...
# 8  Important Shiba Inu (SHIB) Metrics Soar as Pri...
# 9  Ethereum Price Analysis: ETH Holds at $3K but ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/65/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df65 = pd.DataFrame({'headline_news':headline_news})
df65
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 65 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Bitcoin Price Analysis: BTC Recovers $57K but ...
# 1  Hong Kong Boy Kidnapped, Ransom Demanded in US...
# 2  Web3 Users Surge by 40%, Reaching Historic Hig...
# 3  What Caused the Majority of Crypto Thefts in Q...
# 4  QCP Capital Predicts ‘Subdued’ Bitcoin Perform...
# 5  Time to Buy the Bitcoin Dip? Experts Weigh in ...
# 6  We Asked ChatGPT Which Meme Coin Will Perform ...
# 7  Bitcoin Recovers Above $56K as Altcoins Also B...
# 8  Can XRP Price Reach $1 in July if the Ripple v...
# 9  PancakeSwap to Distribute 2.45M ZK (zkSync) To...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/66/')
print(type(request))
soup =BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df66 = pd.DataFrame({'headline_news':headline_news})
df66
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 66 of 2266 | CryptoPotato</title>
#                                        headline_news
# 0  Sam Bankman-Fried Family’s Deep Involvement in...
# 1  Very Few Bitcoin Mining Machines Profitable Be...
# 2  Is Bitcoin Undervalued? Core Scientific Founde...
# 3  ‘Buy Bitcoin (BTC)’ Searches Soar Amid the Rec...
# 4  HODL Instead of Sell: German MP Criticizes Gov...
# 5  Crypto Bloodbath: Bitcoin and Altcoins Plummet...
# 6  More Details About the Mt. Gox Bitcoin Repayme...
# 7  Crypto Price Analysis July-05: ETH, XRP, ADA, ...
# 8      Why is the Shiba Inu (SHIB) Price Down Today?
# 9  Will Markets Tank Further as $1.5B as Crypto O...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/67/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df67 = pd.DataFrame({'headline_news':headline_news})
df67
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/68/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df68 = pd.DataFrame({'headline_news':headline_news})
df68
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/69/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df69 = pd.DataFrame({'headline_news':headline_news})
df69
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/70/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df70 = pd.DataFrame({'headline_news':headline_news})
df70
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/71/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df71 = pd.DataFrame({'headline_news':headline_news})
df71
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/72/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df72 = pd.DataFrame({'headline_news':headline_news})
df72
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/73/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df73 = pd.DataFrame({'headline_news':headline_news})
df73
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/74/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df74 = pd.DataFrame({'headline_news':headline_news})
df74
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/75/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df75 = pd.DataFrame({'headline_news':headline_news})
df75
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/76/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df76 = pd.DataFrame({'headline_news':headline_news})
df76
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/77/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df77 = pd.DataFrame({'headline_news':headline_news})
df77
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/78/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df78 = pd.DataFrame({'headline_news':headline_news})
df78
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/79/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df79 = pd.DataFrame({'headline_news':headline_news})
df79
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/80/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df80 = pd.DataFrame({'headline_news':headline_news})
df80
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/81/')
print(type(request))
soup =BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df81 = pd.DataFrame({'headline_news':headline_news})
df81
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/82/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df82 = pd.DataFrame({'headline_news':headline_news})
df82
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/83/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df83 = pd.DataFrame({'headline_news':headline_news})
df83
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/84/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df84 = pd.DataFrame({'headline_news':headline_news})
df84
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/85/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df85 = pd.DataFrame({'headline_news':headline_news})
df85
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/86/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df86 = pd.DataFrame({'headline_news':headline_news})
df86
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/87/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df87 = pd.DataFrame({'headline_news':headline_news})
df87
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/88/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df88 = pd.DataFrame({'headline_news':headline_news})
df88
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/89/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df89 = pd.DataFrame({'headline_news':headline_news})
df89
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/90/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df90 = pd.DataFrame({'headline_news':headline_news})
df90
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/91/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df91 = pd.DataFrame({'headline_news':headline_news})
df91
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/92/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df92 = pd.DataFrame({'headline_news':headline_news})
df92
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/93/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df93 = pd.DataFrame({'headline_news':headline_news})
df93
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/94/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df94 = pd.DataFrame({'headline_news':headline_news})
df94
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/95/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df95 = pd.DataFrame({'headline_news':headline_news})
df95
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/96/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df96 = pd.DataFrame({'headline_news':headline_news})
df96
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/97/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df97 = pd.DataFrame({'headline_news':headline_news})
df97
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/98/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df98 = pd.DataFrame({'headline_news':headline_news})
df98
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/99/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df99 = pd.DataFrame({'headline_news':headline_news})
df99
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/100/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df100 = pd.DataFrame({'headline_news':headline_news})
df100
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
news_df = pd.concat([news_df,df18,df19,df20,df21,df23,df24,df25,df26,df27,df28,df29,df30,df31,df32,df33,
                    df34,df35,df36,df37,df38,df39,df40,df41,df42,df43,df44,df45,df46,df47,df48,df49,df50,
                    df51,df52,df53,df54,df55,df56,df57,df58,df59,df60,
                    df61,df62,df63,df64,df65,df66,df67,df68,df69,df70,
                    df71,df72,df73,df74,df75,df76,df77,df78,df79,df80,
                    df81,df82,df83,df84,df85,df86,df87,df88,df89,df90,
                    df91,df92,df93,df94,df95,df96,df97,df98,df99,df100],
                   axis = 0)

# %%
news_df
# Out:
#                                         headline_news
# 0                                  Latest Crypto News
# 1   Self-custodial Bitcoin staking protocol Babylo...
# 2   AC Milan inks new sponsorship deal with crypto...
# 3   Bitwise expands into Europe with acquisition o...
# 4   Binance to support Frontier (FRONT) token swap...
# ..                                                ...
# 5   Crypto Bloodbath: Bitcoin and Altcoins Plummet...
# 6   More Details About the Mt. Gox Bitcoin Repayme...
# 7   Crypto Price Analysis July-05: ETH, XRP, ADA, ...
# 8       Why is the Shiba Inu (SHIB) Price Down Today?
# 9   Will Markets Tank Further as $1.5B as Crypto O...
#
# [757 rows x 1 columns]

# %%
news_df = news_df.reset_index(drop = True)

# %%
news_df
# Out:
#                                          headline_news
# 0                                   Latest Crypto News
# 1    Self-custodial Bitcoin staking protocol Babylo...
# 2    AC Milan inks new sponsorship deal with crypto...
# 3    Bitwise expands into Europe with acquisition o...
# 4    Binance to support Frontier (FRONT) token swap...
# ..                                                 ...
# 752  Crypto Bloodbath: Bitcoin and Altcoins Plummet...
# 753  More Details About the Mt. Gox Bitcoin Repayme...
# 754  Crypto Price Analysis July-05: ETH, XRP, ADA, ...
# 755      Why is the Shiba Inu (SHIB) Price Down Today?
# 756  Will Markets Tank Further as $1.5B as Crypto O...
#
# [757 rows x 1 columns]

# %%
pd.set_option('display.max_colwidth', None)  # Display the full width of each column
pd.set_option('display.expand_frame_repr', False)  # Prevent line wrapping to ensure the DataFrame is displayed in one line

# %%
news_df
# Out:
#                                                                                                                      headline_news
# 0                                                                                                               Latest Crypto News
# 1                                                                Self-custodial Bitcoin staking protocol Babylon announces mainnet
# 2                                                                AC Milan inks new sponsorship deal with crypto exchange, Bitpanda
# 3                                                                        Bitwise expands into Europe with acquisition of ETC Group
# 4                                                                    Binance to support Frontier (FRONT) token swap and rebranding
# ..                                                                                                                             ...
# ...

# %%
news_df.head(10)
# Out:
#                                                                     headline_news
# 0                            Bitcoin miner Marathon Digital is mining Kaspa (KAS)
# 1                    Cryptocurrencies waver as focus shifts to BitBot token claim
# 2                    Cryptocurrencies waver as focus shifts to BitBot token claim
# 3                US government transfers 3,940 BTC worth $241 million to Coinbase
# 4  German’s BKA transfers more Bitcoin to exchanges including Kraken and Bitstamp
# 5                  Crypto Fear and Greed Index hits 30, lowest level in 18 months
# 6                Donald Trump receives $2M Bitcoin donation from Winklevoss twins
# 7                      Bitcoin stays above $65k as Bitbot unveils its Mini App UI
# 8                           Riot Platforms wants to buy Bitfarms for $950 million
# 9       Notcoin price soars after beating Bitcoin in vote post NOT Airdrop launch

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/101/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df101 = pd.DataFrame({'headline_news':headline_news})
df101
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/102/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df102 = pd.DataFrame({'headline_news':headline_news})
df102
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/103/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df103 = pd.DataFrame({'headline_news':headline_news})
df103
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/104/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df104 = pd.DataFrame({'headline_news':headline_news})
df104
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/105/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df105 = pd.DataFrame({'headline_news':headline_news})
df105
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/106/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df106 = pd.DataFrame({'headline_news':headline_news})
df106
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/107/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df107 = pd.DataFrame({'headline_news':headline_news})
df107
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/108/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df108 = pd.DataFrame({'headline_news':headline_news})
df108
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/109/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df109 = pd.DataFrame({'headline_news':headline_news})
df109
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/110/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df110 = pd.DataFrame({'headline_news':headline_news})
df110
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/111/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df111 = pd.DataFrame({'headline_news':headline_news})
df111
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/112/')
print(type(request))
soup =BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df112 = pd.DataFrame({'headline_news':headline_news})
df112
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/113/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df113 = pd.DataFrame({'headline_news':headline_news})
df113
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/114/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df114 = pd.DataFrame({'headline_news':headline_news})
df114
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/115/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df115 = pd.DataFrame({'headline_news':headline_news})
df115
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 115 of 2188 | CryptoPotato</title>
#                                                                                  headline_news
# 0                 Satoshi Era Miner Wakes From 14-Year Slumber, Moves 50 BTC to Coinbase: Data
# 1             Is the Worst Over for ETH Following the Dip Below $3K? (Ethereum Price Analysis)
# 2    Two Critical Levels to Watch in BTC Following the Weekend Wipeout: Bitcoin Price Analysis
# 3  Is XRP in Danger of Falling Toward $0.40 Following the Recent Dump? (Ripple Price Analysis)
# 4                Important Ripple vs. SEC Development This Week: Is a Settlement in the Cards?
# 5          Polkadot Price Analysis: DOT Crashes Over 30% But Finds Support at $6, What’s Next?
# 6                           Much Anticipated Solana Update Goes Live to Fix Network Congestion
# 7    Extreme Ripple Price Prediction: Analyst Forecasts An Explosive 3000% Upward Move for XRP
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/116/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df116 = pd.DataFrame({'headline_news':headline_news})
df116
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 116 of 2188 | CryptoPotato</title>
#                                                                                            headline_news
# 0                          Hong Kong Greenlights Spot Bitcoin and Ethereum ETFs as Crypto Market Bounces
# 1  Bitcoin (BTC) Price Crash, Shiba Inu (SHIB) Developments, Ripple (XRP) Forecasts: Bits Recap April 15
# 2                                  Can Crypto Markets Recover on This Week’s Economic Data and Earnings?
# 3                    German Investors Increasing Crypto Investments Ahead of Bitcoin Halving: KPMG Study
# 4                                          Bitrace Trains Hong Kong Police on Crypto Crime Investigation
# 5                                         Bitget’s Futures Trading Hits $1.4 Trillion in Q1 2024: Report
# 6                                           Ripple Price Predictions Amid the Crash: Where’s XRP Headed?
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/117/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df117 = pd.DataFrame({'headline_news':headline_news})
df117
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 117 of 2188 | CryptoPotato</title>
#                                                                                headline_news
# 0                            Coinbase Files Appeal Over ‘Investment Contracts’ in SEC Battle
# 1              Mempool Founder Mononaut Raises Red Flag Over Bitcoin Layer 2 Implementations
# 2  Crypto Markets Lost Over $400B as Bitcoin (BTC) Slumped by $10K in 2 Days (Weekend Watch)
# 3                     Ethereum Layer 2 Transaction Explosion: 200% Surge Post-Dencun Upgrade
# 4                         Ethereum Restaking Platform EigenLayer Launches EigenDA to Mainnet
# 5   Peter Schiff Takes a Dig at Bitcoin as BTC Price Tumbles Amid Rising Iran-Israel Tension
# 6                              US Treasury: Russia Turns to Tether (USDT) to Evade Sanctions
# 7    Another $700 Million in Liquidations as Bitcoin (BTC) Dumps to $61K, Altcoins Bleed Out
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/118/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df118 = pd.DataFrame({'headline_news':headline_news})
df118
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 118 of 2188 | CryptoPotato</title>
#                                                                                  headline_news
# 0         We Asked ChatGPT if Bitcoin’s (BTC) Market Cap Can Hit $3 Trillion After the Halving
# 1            Here’s Why the Effect of Bitcoin Halving is Diminishing, According to CryptoQuant
# 2                        Top Recent Shiba Inu Price Predictions: Where is SHIB Headed in 2024?
# 3  These Crypto Assets Dumped the Most as the Total Market Cap Shed Over $200B (Weekend Watch)
# 4     Not Just Bitcoin: Gold’s Price Dropped 4% in Hours After Fed’s Latest Rate Cuts Comments
# 5                 Chainlink Price Predictions: Is LINK Ready to ‘Moon’ During This Bull Cycle?
# 6          FBI Reportedly Subpoenas Brink Exec for Info on Bitcoin Event Tied to Dashjr’s Hack
# 7                                    LINK Prices Lifted Following Chainlink Transporter Launch
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/119/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df119 = pd.DataFrame({'headline_news':headline_news})
df119
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 119 of 2188 | CryptoPotato</title>
#                                                                                              headline_news
# 0                               Bitcoin (BTC) Price Tumbles $6K, Liquidations Skyrocket to $500M in 1 Hour
# 1                                             Do Kwon’s Fate Hangs in Limbo, Signs Point to US Extradition
# 2                                       Bitcoin (BTC) Could Witness Further Price Declines if This Happens
# 3                                BlackRock’s Spot Bitcoin ETF Surpasses Another Massive Milestone: Details
# 4      Polkadot Price Analysis: DOT Reaches a Significant Decision Point as Bears Unable to Break Below $8
# 5                           XRP Needs to Break This Level for the Bull Run to Resum: Ripple Price Analysis
# 6  Bitcoin’s Wild Ride Around $70K, Uniswap v. SEC Clash in the Making, and More: This Week’s Crypto Recap
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/120/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df120 = pd.DataFrame({'headline_news':headline_news})
df120
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 120 of 2188 | CryptoPotato</title>
#                                                                             headline_news
# 0        Key Shiba Inu Metric Skyrockets by 4,000%: What Does it Mean for the SHIB Price?
# 1               FTT Soared 15% After SBF Appealed Fraud Conviction and 25-Year Sentencing
# 2  BTC Maintains $70K Despite Heightened GBTC Outflows, WIF Plummets Again (Market Watch)
# 3            This Bitcoin-Related Meme Coin Explodes by Almost 3,000% in a Month: Details
# 4                          Can Bitcoin Return to ATH When $1.5B BTC Options Expire Today?
# 5                     Robert Kiyosaki Concurs With Cathie Wood’s $2.3M Bitcoin Prediction
# 6                      Ordinals Activity Ramps Up Before Halving — Alongside Bitcoin Fees
# 7                       Voyager Digital Secures $484 Million from FTX and 3AC Settlements
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/121/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df121 = pd.DataFrame({'headline_news':headline_news})
df121
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 121 of 2188 | CryptoPotato</title>
#                                                                                    headline_news
# 0                   Don’t Expect Another Lawsuit If SEC Rejects Ethereum ETFs: Bloomberg Analyst
# 1               Meme Coins Dominate Profit Distribution Among Altcoins as BTC Rallies Above $70K
# 2                  Here’s Why Cardano (ADA) Might be Gearing up for a 200% Price Rally (Analyst)
# 3                  This Bullish BTC Indicator Suggests Upside Above $70K: Bitcoin Price Analysis
# 4                         Bitcoin (BTC) Becomes Even More Secure Just Days Ahead of 2024 Halving
# 5                                VeChain Price Predictions: a 25% Increase or a New ATH for VET?
# 6                                   3 Uniswap (UNI) Whales Offload $20M After SEC’s Wells Notice
# 7         Will Ripple (XRP) Price Follow Bitcoin and Reach a New All-Time High? Analyst Chips In
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/122/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df122 = pd.DataFrame({'headline_news':headline_news})
df122
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 122 of 2188 | CryptoPotato</title>
#                                                                                               headline_news
# 0                                                 Shiba Inu (SHIB) Burn Rate Skyrockets by 50,000%: Details
# 1                 UNI Slumps 17% Following SEC Developments, BTC, ETH, DOGE, TON on the Rise (Market Watch)
# 2                             This Popular AI Cryptocurrency Explodes by 15% Following Support From Binance
# 3  Shiba Inu (SHIB) Predictions, Bitcoin (BTC) Price Swings, Ripple (XRP) Developments: Bits Recap April 11
# 4                                        Grayscale CEO Expects GBTC Outflows to ‘Reach Equilibrium:’ Report
# 5                                                            SEC Files Notice Of Intent To Sue Uniswap Labs
# 6                                                   Circle’s USDC Stablecoin Lands on zkSync Layer 2 Rollup
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/123/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df123 = pd.DataFrame({'headline_news':headline_news})
df123
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 123 of 2188 | CryptoPotato</title>
#                                                                                headline_news
# 0                                        Institutions Are Levering Up On Bitcoin In This ETF
# 1            Permissionless Capital Opens Applications For Web3 Startups Opportunities Event
# 2  Solana Above Critical Support, Will $164 Hold? Three Things to Watch (SOL Price Analysis)
# 3       ETH Slides Below $3.5K But Bullish Presence Remains Strong (Ethereum Price Analysis)
# 4         Two Critical Factors to Consider for DOT as Bulls Eye $10: Polkadot Price Analysis
# 5                  Here’s How Much Shiba Inu (SHIB) and Ripple (XRP) Binance Currently Holds
# 6                     $300M Liquidated Amid BTC’s Rollecoaster After the US CPI Announcement
# 7                     USDT Weekly Transaction Volume on Tron 2x Higher Than on Ethereum: ITB
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/124/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df124 = pd.DataFrame({'headline_news':headline_news})
df124
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 124 of 2188 | CryptoPotato</title>
#                                                                         headline_news
# 0                        Here’s When Hong Kong Will Announce its Bitcoin ETFs: Report
# 1   Crypto Markets in Retreat: BTC Losses $70K, WIF Plummets 11% Daily (Market Watch)
# 2              Shiba Inu Developer Makes an Important Announcement: Bullish for SHIB?
# 3               Dogecoin (DOGE) Must Break Above This Level To Reach New ATH: Details
# 4                    Bitcoin (BTC) Halving Rally Already Priced in, Says Marathon CEO
# 5           SEC Delays Decision on NYSE Proposal for Spot Bitcoin ETF Options Trading
# 6                    How Much Do Bitcoin ETFs Actually Matter? Glassnode Investigates
# 7  Filecoin’s Liquid Staking Platform Core Team Under Investigation by Chinese Police
# 8                      USDC Issuer Circle Expands Support for Web3 Services on Solana
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/125/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df125 = pd.DataFrame({'headline_news':headline_news})
df125
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 125 of 2188 | CryptoPotato</title>
#                                                                         headline_news
# 0                    Binance Has Matured Since DOJ $4.3B Settlement: CEO Richard Teng
# 1                           Polkadot Selects Indy 500 Brand Ambassador Via Blockchain
# 2                  AI and Big Data, Liquid Staking, DeFi Capture Biggest Weekly Gains
# 3                     Analyst Raises Bitcoin (BTC) Price Forecast to $150,000 by 2025
# 4                  Ethereum (ETH) Surges Ahead with Ultra-Strong Activity: LunarCrush
# 5  Bitcoin Itching for a New All-Time High But Bears Defend $72K (BTC Price Analysis)
# 6          Ripple Price Analysis: XRP Soars 8% This Week, Are the Bulls Back in Town?
# 7                                             Why is the Ripple (XRP) Price Up Today?
# 8       This Is How BTC Could Hit $150K 14 Months Post-Halving, According to Bitfinex
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/126/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df126 = pd.DataFrame({'headline_news':headline_news})
df126
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 126 of 2188 | CryptoPotato</title>
#                                                                                                          headline_news
# 0  AI Will be One of those Areas Where Blockchain has Genuinely Improved: Flare Network’s CEO Hugo Philion (Interview)
# 1                                      Here’s Why Arthur Hayes Warns of Pre and Post-Halving Slump for Bitcoin’s Price
# 2                                      This Popular Altcoin Skyrockets by 70% Following Support From Coinbase: Details
# 3                          TON Defies Market Sentiment With a Massive 23% Surge, BTC Slumps Toward $70K (Market Watch)
# 4                                                       Dogecoin Price Prediction: When is the DOGE Bull Run Starting?
# 5                                                    Spot Bitcoin ETFs Outflow Net $224M Despite BTC’s Jump Above $72K
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/127/')
print(type(request))
soup = bs4.BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df127 = pd.DataFrame({'headline_news':headline_news})
df127
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 127 of 2188 | CryptoPotato</title>
#                                                                               headline_news
# 0                         Swaap Labs Launches “Supercharged” DeFi Yield Protocol Swaap Earn
# 1  China’s Largest Equity Funds Pursue Spot Bitcoin ETFs via Hong Kong Subsidiaries: Report
# 2                                      Ripple’s CEO With a Very Bullish Prediction for 2024
# 3              dYdX Community Approves 20 Million Token Stake Amidst Rising Trading Volumes
# 4           This Trader Reportedly Lost $800k in Crypto Through Malicious Chrome Extensions
# 5             Here’s the Number of Bitcoin Addresses at a Loss as BTC Retests Its ATH Price
# 6     Ripple (XRP) Bull Run to Return? This Level Needs to Fall First According to Analysts
# 7                             Ethereum Price Analysis: ETH Explodes 7% Dailys, is $4K Next?
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/128/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df128 = pd.DataFrame({'headline_news':headline_news})
df128
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 128 of 2188 | CryptoPotato</title>
#                                                                                                    headline_news
# 0                                          Arthur Hayes Offloads 237K GMX After 2 Years, Here’s His Profit: Data
# 1                                    Shiba Inu Burn Rate Explodes by 300% Amid Renewed SHIB Price Rally: Details
# 2                         Spot Bitcoin ETF Flows Expected to Maintain Strength Ahead of Halving as BTC Taps $72K
# 3                                                                     Why is the Dogecoin (DOGE) Price Up Today?
# 4                                              Polkadot Price Prediction: Is DOT About to Rally Toward $15 Soon?
# 5                           Crypto Markets Add $70 Billion Daily as Bitcoin (BTC) Soars Past $71K (Market Watch)
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/129/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df129 = pd.DataFrame({'headline_news':headline_news})
df129
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 129 of 2188 | CryptoPotato</title>
#                                                                                 headline_news
# 0      Ethereum’s Layer 2 Networks Projected to Reach $1T Market Cap by 2030: VanEck Analysts
# 1                       OneCoin’s Head of Legal and Compliance Sentenced to 4 Years in Prison
# 2          Google Sues 2 Individuals for Alleged Crypto Investment Fraud Using its Play Store
# 3                         Ethereum and Polygon Attract Majority of New Users: Flipside Report
# 4  This Is What We Can Expect After the 2024 Bitcoin Halving According to Historical Patterns
# 5                           Cathie Wood’s ARK Invest Accidentally Owns $15,000 Bitcoin Puppet
# 6                 Ethereum’s Q1 2024 Revenue Soars to $1.2 Billion, Marking 155% YoY Increase
# 7                         Bitcoin Sees Third Best Quarterly Trading Volume in 3 Years: Report
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/130/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df130 = pd.DataFrame({'headline_news':headline_news})
df130
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 130 of 2188 | CryptoPotato</title>
#                                                                                headline_news
# 0                           DApp Activity Sees Surge Amid Bitcoin’s All-Time High in Q1 2024
# 1      3 Suspects Arrested as Hong Kong Police Rescue Teen in Crypto-Related Attack (Report)
# 2                               Is This Bitcoin Halving Strategy Indeed the Most Profitable?
# 3  Bithumb Korea’s Fiscal Performance in 2023 Plummets Despite Rising Trading Volume: Report
# 4                         Restaking Emerges as Ethereum’s Second Largest DeFi Sector: Report
# 5     DOGE at $1, XRP to $5.25, BTC Close to $200,000: Outrageous Price Predictions for 2025
# 6                     Bitcoin Miners Compete for Profitability Ahead of Halving: CryptoQuant
# 7                  World’s First Bitcoin ETF Has Lost 20% of Assets Since BlackRock Approval
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/131/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df131 = pd.DataFrame({'headline_news':headline_news})
df131
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 131 of 2188 | CryptoPotato</title>
#                                                                                                                    headline_news
# 0                                                               Will SHIB and DOGE Skyrocket After the Upcoming Bitcoin Halving?
# 1                                                           Ethena Labs Adds Bitcoin Backing to its Synthetic Dollar-pegged USDe
# 2                                                       5 Years Later: Uniswap Surpasses $2 Trillion Milestone in Trading Volume
# 3                                                                           Is Solana Facing an Existential Threat Like FTX Did?
# 4                                                           XRP Tumbles Below $0.6 as Bears Take Control (Ripple Price Analysis)
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/132/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df132 = pd.DataFrame({'headline_news':headline_news})
df132
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 132 of 2188 | CryptoPotato</title>
#                                                                                  headline_news
# 0                   Shiba Inu (SHIB) Receives Support by This Popular Crypto Platform: Details
# 1  How Is the US Related to Bitcoin’s (BTC) Price Drop to $64.5K This Week? Santiment Observes
# 2     Bitcoin’s Current 18% Retrace Is Right on Schedule and Is Actually Good News: Here’s Why
# 3                             Here Are 5 Reasons Why Shiba Inu’s (SHIB) Price Could Rally Soon
# 4                         Bitcoin (BTC) Price Will Not Drop Below This Level Again, Says PlanB
# 5   WIF Plummets by 15% Overnight, BTC Recovery Begins by Reclaiming $67K Level (Market Watch)
# 6                      Will Crypto Markets Keep Falling as $1.2B Bitcoin Options Expire Today?
# 7                    Is a New Dogecoin (DOGE) Bull Run on the Horizon? These Analysts Think so
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/133/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df133 = pd.DataFrame({'headline_news':headline_news})
df133
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 133 of 2188 | CryptoPotato</title>
#                                                                     headline_news
# 0                             Pyth Network Unveils Price Feeds For W/USD And USDB
# 1    Crypto VC Comeback: Paradigm, Galaxy Digital to Raise Millions for New Funds
# 2        Coinbase’s Base Transaction Volume Surpasses $1.6B: ‘Base Spring Ahead’?
# 3                     Which Will be the Top Meme Coins in April? ChatGPT Analyzes
# 4                          Binance Plans To End Support For Bitcoin Ordinals NFTs
# 5           Here’s When We Can Expect Bitcoin’s Price Top After the April Halving
# 6                     Crypto Price Analysis Apr-04: ETH, XRP, ADA, SHIB, and DOGE
# 7                 Ripple Announces the Launch of a Stablecoin Pegged to US Dollar
# 8  Spot Bitcoin ETF Flows Shift Positively as Grayscale’s GBTC Outflows Slow Down
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/134/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df134 = pd.DataFrame({'headline_news':headline_news})
df134
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 134 of 2188 | CryptoPotato</title>
#                                                                                             headline_news
# 0                                                  Record Number of New Traders Flock to Meme Coins: Data
# 1                                          Ripple Price Prediction: Is XRP Still on Track to $1 in April?
# 2                                                             New Meme Coin Trend? Cat Tokens Taking Over
# 3                      BCH Soars 10% After Completing Second Halving, BTC Sluggish at $66K (Market Watch)
# 4  Upcoming Ripple (XRP) Events, Shiba Inu (SHIB) Achievements, Bitcoin Price Decline: Bits Recap April 4
# 5                                       Bitcoin Is an Insurance Policy Against Rogue Regimes: Cathie Wood
# 6                       Asian Bitcoin Investors Face Volatility Due to Automated ETF Trading Bots: Report
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/135/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df135 = pd.DataFrame({'headline_news':headline_news})
df135
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 135 of 2188 | CryptoPotato</title>
#                                                                             headline_news
# 0          ZachXBT Exposes NFT Project Creator of Fabricating Hack to Buy DeGods and y00t
# 1     Coinbase Moves Forward On Lightning Network Integration With Lightspark Partnership
# 2  Robert Kiyosaki to Purchase More BTC If This Devastating Bitcoin Prediction Comes True
# 3        Shiba Inu (SHIB) is the Most-Traded Coin in March on The Leading Indian Exchange
# 4             Bitcoin Bounces off $65K But is There More Pain Ahead? (BTC Price Analysis)
# 5                        KuCoin’s Market Share Declines by 50% After DOJ and CTFC Charges
# 6        Cathie Wood’s ARK Bitcoin ETF Records Daily Outflows Surpassing Grayscale’s GBTC
# 7                         Shiba Inu (SHIB) Blasts Through Another Huge Milestone: Details
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/136/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df136 = pd.DataFrame({'headline_news':headline_news})
df136
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 136 of 2188 | CryptoPotato</title>
#                                                                                  headline_news
# 0  BTC’s Recovery Begins After a 10-Day Low, ICP Steals the Show With 10% Surge (Market Watch)
# 1        Rising Bitcoin Realized Cap Points to Fresh Capital Inflow, But BTC Dipped Below $65K
# 2             Time to Buy Dogecoin (DOGE) Before it Pops to $1? This Popular Analyst Thinks So
# 3                                    This DEX Just Launched the First Decentralized Crypto ETF
# 4                            Vitalik Buterin Says Layer 3s Won’t Magically Increase Throughput
# 5                                              Ripple v. SEC Lawsuit: What to Expect in April?
# 6                                 U.S. Government Moves To Sell More Bitcoin Tied To Silk Road
# 7                              This April Fools Joke Ends With a 25% Loss for Crypto Investors
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/137/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df137 = pd.DataFrame({'headline_news':headline_news})
df137
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 137 of 2188 | CryptoPotato</title>
#                                                                                             headline_news
# 0                             Bitcoin’s (BTC) Dump Below $65K Fails to Fizzle Crowd Confidence: Santiment
# 1                         Ethereum Slides Near Three Year Low Against Bitcoin Amid Crypto Market Pullback
# 2                                     Coinbase Sees Second-Largest Bitcoin Outflow Amid Market Correction
# 3                   Bitcoin Investors Continue to Take Profit as BTC Price Slides to 10-Day Low: Bitfinex
# 4                     Two Critical Levels to Watch for XRP Following the 8% Crash (Ripple Price Analysis)
# 5                                                  This Is What SBF Had to Say After His 25-Year Sentence
# 6                             Ethereum Price Analysis: Is $3K Next for ETH or Will the Bulls Bounce Back?
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/138/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df138 = pd.DataFrame({'headline_news':headline_news})
df138
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 138 of 2188 | CryptoPotato</title>
#                                                                             headline_news
# 0                     Here’s What Drove Bitcoin’s Price Down to $65.5K in Hours: Analysis
# 1                    Bitcoin Tumbles Below $67K as Solana Crashes 6% Daily (Market Watch)
# 2         Shiba Inu Price Prediction: SHIB Patterns Indicate Incoming Gains, Analyst Says
# 3                          Dogecoin (DOGE) Price Crashes 14% Amid Broader Market Pullback
# 4  $500 Million in Liquidations as BTC Dumps to $66K, DOGE and SHIB Plummet Double Digits
# 5                          Bitcoin Nosedives $3K in Latest Flush Out But Analysts Unfazed
# 6                                   Tether Completes SOC 2 Type 1 Security Audit: Details
# 7             DeFi Sector Grapples with $187M Losses But Recovery Efforts Net Nearly $99M
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/139/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df139 = pd.DataFrame({'headline_news':headline_news})
df139
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 139 of 2188 | CryptoPotato</title>
#                                                                                             headline_news
# 0                                   Argentina Announces Mandatory Registry For Bitcoin And Crypto Trading
# 1                                                  Here’s Why Toncoin (TON) Price is Up Over 130% in 2024
# 2                                                              Why is the Dogecoin (DOGE) Price Up Today?
# 3                                  Dogecoin Price Prediction: Is a Parabolic DOGE Bull Run in the Making?
# 4                              Here’s Why Bitwise CEO Wants the SEC to Postpone Approval of Ethereum ETFs
# 5  BTC Dump Incoming? Worrying Patterns Appear as Bulls Remain Uncertain at $70K (Bitcoin Price Analysis)
# 6                                   Should You Buy Shiba Inu (SHIB) Now? This Bitcoin Proponent Thinks So
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/140/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df140 = pd.DataFrame({'headline_news':headline_news})
df140
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 140 of 2188 | CryptoPotato</title>
#                                                                                            headline_news
# 0                     Stablecoin Issuer Tether Strengthens Bitcoin Portfolio with $627M Bitcoin Purchase
# 1                          Massive Increase in Shiba Inu Burn Rate as SHIB Bull Run Accelerated in March
# 2                Bitcoin Loses $70K Level, Bitcoin Cash Soars 12% Ahead of Second Halving (Market Watch)
# 3  Dogecoin’s Bull Run, Bitcoin (BTC) Uncertainty Around $70K, Dogwifhat (WIF) Rally: Bits Recap April 1
# 4                                 Will Crypto Markets Climb or Fall on This Week’s Big US Economic Data?
# 5                                  What is Driving Meme Coin Madness in The ‘Weirdest Bull Market Ever?’
# 6                  South Korean Police Nabs 2 Fraudsters After Senior Citizen Loses $4.1M in Crypto Scam
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/141/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df141 = pd.DataFrame({'headline_news':headline_news})
df141
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 141 of 2188 | CryptoPotato</title>
#                                                                               headline_news
# 0         Gaza Now and London-Based Businesses Targeted in US-UK Crypto Terrorism Crackdown
# 1         Solana Meme Coin Mania Far From Over as This New Contender Explodes 10x in 3 Days
# 2                    FCA Targets Meme Coin ‘Finfluencers’ with New Guidelines on Promotions
# 3                         Bitcoin Price Analysis: Is BTC on the Verge of Exploding to $75K?
# 4        Calm Before the Storm for XRP: Is a Massive Move Imminent? (Ripple Price Analysis)
# 5  WIF and These Assets Explode by Double Digits Weekly, BTC Maintains $70K (Weekend Watch)
# 6      SBF-Related Meme Coin Pumps and Dumps Following his 25-Year Prison Sentence: Details
# 7                     Grayscale Launches New Institutional Crypto Fund With Staking Rewards
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/142/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df142 = pd.DataFrame({'headline_news':headline_news})
df142
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 142 of 2188 | CryptoPotato</title>
#                                                                                   headline_news
# 0                     Here’s How Bitcoin (BTC) Can Reach $150,000 This Year: Hedge Fund Manager
# 1  Bitcoin Faces Sell-Side Liquidity Crisis as Demand Reaches Unprecedented Levels: CryptoQuant
# 2                   Bitcoin Has More Users Than The Internet in 1997: Here’s Why That’s Bullish
# 3              Bitcoin (BTC) Price Still Shaky at $70K, Solana (SOL) Nears $200 (Weekend Watch)
# 4                                        ChatGPT Analyzes if Dogecoin (DOGE) Can Hit $1 in 2024
# 5                     Binance Executive Takes Legal Action Against Nigerian Authorities: Report
# 6                                             Binance-Linked HKVAEX Withdraws Hong Kong License
# 7                               BOTTO, TOKEN, and AGIX Lead Market Cap Surge in AI and Big Data
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/143/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df143 = pd.DataFrame({'headline_news':headline_news})
df143
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 143 of 2188 | CryptoPotato</title>
#                                                                                  headline_news
# 0                 Will Bitcoin (BTC) Break its $73.8K ATH Following This Record USDC Transfer?
# 1     Dogecoin Explodes 50% as Bitcoin Bitcoin Bulls Return in Force: This Week’s Crypto Recap
# 2               Crypto Sensation WIF Flips PEPE to Become the Third-Biggest Meme Coin: Details
# 3         Bullish for Shiba Inu? Whale Withdraws 2 Trillion SHIB From Troubled Exchange KuCoin
# 4                                  Crypto Price Analysis Mar-29: ETH, XRP, ADA, SHIB, and DOGE
# 5                      Spot Bitcoin ETFs Record $183 Million Daily Net Inflow as BTC Taps $70K
# 6                   Prisma Finance Hacker Claims ‘Whitehat Rescue’ After $11.6 Million Exploit
# 7  Are Dogecoin (DOGE) and Shiba Inu (SHIB) Poised for Further Gains? Popular Analyst Chips in
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/144/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df144 = pd.DataFrame({'headline_news':headline_news})
df144
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 144 of 2188 | CryptoPotato</title>
#                                                                           headline_news
# 0  Solana (SOL) Price Prediction: Is $300 Possible After the Bitcoin Halving? (Analyst)
# 1            A Whopping $15B in Crypto Options Are About to Expire, Will Markets React?
# 2                      British Columbia Courts Target Quadriga CX Exec’s Wealth Origins
# 3                       USDT Transaction Volume Soars on TRON DAO, Hits 2 Million Daily
# 4                       Ethereum Hits 1 Million Validators Prompting Community Concerns
# 5                   Ripple (XRP) Bashed by Forbes: Cardano’s Charles Hoskinson Responds
# 6        Here’s Why Bitcoin ETF Flows Will Continue for Years, According to Bitwise CIO
# 7                           Vitalik Explains Ethereum’s Next Steps After Dencun Upgrade
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/145/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df145 = pd.DataFrame({'headline_news':headline_news})
df145
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 145 of 2188 | CryptoPotato</title>
#                                                                              headline_news
# 0            4 Days Ahead of Halving: Bitcoin Cash Price Soars Alongside BCH Open Interest
# 1            Ethereum ‘Blobs’ Unleash Activity Reminiscent of Bitcoin Ordinals’ Early Days
# 2                                               Why is the Dogecoin (DOGE) Price Up Today?
# 3   BlackRock CEO Remains Confident on Ethereum ETFs, Says IBIT Is The Fastest-Growing ETF
# 4           Important for Dogecoin: This Metric Jumps by Almost 100% Amid DOGE Price Rally
# 5           Dogecoin (DOGE) Explodes 10% Daily, Bitcoin (BTC) Reclaims $70K (Market Watch)
# 6                   Shiba Inu Burn Rate Explodes by 1,200%: Is SHIB Poised for a Bull Run?
# 7  Bitcoin (BTC) Volatility, Ripple (XRP) Price Predictions, and More: Bits Recap March 28
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/146/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df146 = pd.DataFrame({'headline_news':headline_news})
df146
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 146 of 2188 | CryptoPotato</title>
#                                                                              headline_news
# 0                      Hashdex Converts Futures Fund Into Latest US Spot Bitcoin ETF, DEFI
# 1                     US Lawmakers Urge SEC to Confront Prometheum’s Custody Plans for ETH
# 2                     Munchables Hacker Returns Stolen Crypto Funds Worth Over $62 Million
# 3               This Bitcoin OG May Come Back To Development After Craig Wright Court Loss
# 4             Ethereum’s Vitalik Buterin Challenges Hype: Metaverse Is Still Misunderstood
# 5                                       Bitcoin Whale Moves 2,000 BTC Dormant for 14 Years
# 6                    PlanB’s Poll Shows Strong Belief in Bitcoin’s $100k Milestone by 2024
# 7                          COTI Taps Civic to Give Users Self-Sovereign Digital Identities
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/147/')
print(type(request))
soup = bs4.BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df147 = pd.DataFrame({'headline_news':headline_news})
df147
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 147 of 2188 | CryptoPotato</title>
#                                                                               headline_news
# 0                               These Bitcoin ETFs Among Top 30 Asset Funds Listed Globally
# 1   Dogecoin Nears $0.20 Amid Increased Whale Activity: Can the DOGE Price Rally Even More?
# 2               Bitcoin (BTC) Dominance Grows as Altcoins Go in Retrace Mode (Market Watch)
# 3               Shiba Inu (SHIB) Performed Better Than Expected: Ethereum’s Vitalik Buterin
# 4                     Bitcoin Hits Resistance Again as Realized Profits Reach $2.6B Per Day
# 5  US Prosecutors Charge KuCoin for AML Violations: Outflows Skyrocket and KCS Plummets 13%
# 6       Is $160K Conservative for Bitcoin? BTC on the Verge of Another Breakout: Here’s Why
# 7       Pink Drainer Addresses Stake 12M DAI in Spark, Becoming Top sDAI Holder: PeckShield
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/148/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df148 = pd.DataFrame({'headline_news':headline_news})
df148
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 148 of 2188 | CryptoPotato</title>
#                                                                                                       headline_news
# 0                                                  Important Binance Announcement Concerning FLOKI and BONK Traders
# 1                                                 Tether Doubles Down on AI Plans, Looks to Hire Relevant Employees
# 2                                    Fifth Richest Bitcoin Address Transfers $6 Billion in BTC Amid Surge Past $70K
# 3                              Shiba Inu (SHIB) Outperforms Ripple (XRP) and Cardano (ADA) in This Essential Metric
# 4                                    Worldcoin Ordered to Halt Biometric Data Collection in Another Country: Report
# 5  Bullish for BTC? Institutional and Retail Investors’ Appetite for Bitcoin Is Growing, Shows This Coinbase Metric
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/149/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df149 = pd.DataFrame({'headline_news':headline_news})
df149
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 149 of 2188 | CryptoPotato</title>
#                                                                                  headline_news
# 0                          The Best Shiba Inu (SHIB) Alternatives in 2024: Meme Coin Deep Dive
# 1                                     Trending Solana Meme Coin SLERF Soars 35% Daily: Details
# 2                      This Shiba Inu Metric Explodes by 500% Amid a SHIB Price Rally: Details
# 3           Crypto Markets Add $150B Overnight as BTC, ETH Soar to 10-Day Peaks (Market Watch)
# 4                SEC Seeking $2 Billion in Fines From Ripple, According to Chief Legal Officer
# 5                              Spot Bitcoin ETF Flows Return to Positive as BTC Powers to $71K
# 6                               Here’s Why Robert Kiyosaki Wants to Buy More Bitcoin (BTC) Now
# 7            Goldman Sachs Observes Spike in Institutional Interest for Crypto Options: Report
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/150/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df150 = pd.DataFrame({'headline_news':headline_news})
df150
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 150 of 2188 | CryptoPotato</title>
#                                                                               headline_news
# 0   Coinbase’s Base Hits Record $2B in TVL as Demand Surges After Dencun Upgrade Activation
# 1              Ava Labs CEO Warns of Substandard L2 Projects, Says Next Cycle Will Be Worse
# 2                   CommEX Shuts Down Few Months After Taking Over Binance’s Russian Market
# 3  Bitcoin Skyrockets Above $70,000 As BlackRock Deems Asset A “Good Portfolio Diversifier”
# 4           Nigeria Slams Binance With Tax Evasion Charges as Detained Exec Escapes: Report
# 5     Investor Hesitation Blamed as Crypto Investments See $942M Weekly Outflow: CoinShares
# 6  Ripple Price Analysis: XRP Pushes Toward $0.65 as Buyers Resume Control: Is $0.7 Coming?
# 7                       Ethereum Price Analysis: Are ETH Bulls Getting Ready For $4K Again?
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/151/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df151 = pd.DataFrame({'headline_news':headline_news})
df151
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 151 of 2188 | CryptoPotato</title>
#                                                                                                           headline_news
# 0                                                   Ripple Price Prediction: Is XRP on the Verge of a Massive Bull Run?
# 1                                                                             Why is the Ethereum (ETH) Price Up Today?
# 2                              This Bitcoin Metric Signals Caution Despite Attempts to Reclaim $67K: BTC Price Analysis
# 3                                                            Polygon zkEVM Mainnet Beta Back Online After Emergency Fix
# 4                                                Crypto Summer and ‘Banana Zone’ Altseason After BTC Halving: Raoul Pal
# 5                                                     Important Ripple v. SEC Lawsuit Update: What to Expect This Week?
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/152/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df152 = pd.DataFrame({'headline_news':headline_news})
df152
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 152 of 2188 | CryptoPotato</title>
#                                                                                       headline_news
# 0                                Macro Outlook: Will This Week’s Core PCE Data Move Crypto Markets?
# 1                                   SEC Faces Sanctions for ‘Gross Abuse of Power’ in Debt Box Case
# 2                        UK Woman Found Guilty of Laundering Bitcoin Tied to $6 Billion China Fraud
# 3                           Macro Factors to Shape Bitcoin Prices: Coinbase’s Insights Post-Halving
# 4                Cardano Defies Critics With Strong GitHub Activity Among Major Layer 1 Blockchains
# 5  Bitcoin’s 15% Correction Propelled by Profit-Taking but Bull Cycle Is Far From Over: CryptoQuant
# 6            What Will Happen to ETH’s Price if the SEC Rejects All Spot Ethereum ETF Applications?
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/153/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df153 = pd.DataFrame({'headline_news':headline_news})
df153
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 153 of 2188 | CryptoPotato</title>
#                                                                               headline_news
# 0  North Korea Cyberattacks Account for 50% Foreign Currency Earnings, $3B Stolen in Crypto
# 1        Coinbase Wants to Launch Futures Contracts These Crypto Assets on April Fools’ Day
# 2                      Argentinians Turn to Bitcoin Amid Increasing Inflation Rates: Report
# 3         What’s The Best Performing Meme Coin on Social Media? Hint: It’s Not SHIB or DOGE
# 4               Will XRP’s Price Rally as Ripple Gains Support From These Crypto Exchanges?
# 5                                       Big News for XRP Ledger: is an XRP Bull Run Coming?
# 6           TON Defies Market Sentiment With 11% Surge, BTC Falls to $64.5K (Weekend Watch)
# 7                    Will Bitcoin (BTC) Break its $73.8K ATH Before the Halving Next Month?
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/154/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df154 = pd.DataFrame({'headline_news':headline_news})
df154
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 154 of 2188 | CryptoPotato</title>
#                                                                                                                     headline_news
# 0                                              Another Tornado Cash Activity Flagged: Stolen Funds From HECO Bridge Exploit Moved
# 1                                             Google Search Now Displays Wallet Balances for Ethereum Name Services (ENS) Domains
# 2                                                     This Blockchain Game Was Exploited for $4.6 Million Right Before its Launch
# 3                                                            BlackRock Clients View Bitcoin As “Overwhelming” Top Crypto Priority
# 4  Bitcoin Recovery Attempts Halted as ETF Outflows Continue, World’s Biggest Pension Fund Looks at BTC: This Week’s Crypto Recap
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/155/')
print(type(request))
soup = bs4.BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df155 = pd.DataFrame({'headline_news':headline_news})
df155
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 155 of 2188 | CryptoPotato</title>
#                                                                                headline_news
# 0             Bitcoin Struggles at $66K; Ripple’s XRP Defies Bearish Momentum (Market Watch)
# 1              Cardano on the Verge of Achieving a Massive Milestone: ADA Bull Run Imminent?
# 2                                      Spot Bitcoin ETFs See Fourth Straight Day of Outflows
# 3                        Bitcoin Price Crash Incoming? $1.8 Billion BTC Options Expire Today
# 4           This Cryptocurrency Nears an ATH Following Official Listing on Coinbase: Details
# 5        Montenegro’s Court of Appeal Upholds Ruling on Do Kwon’s Extradition to South Korea
# 6  FTX CEO Criticizes SBF’s Bold Claim of ‘Zero’ Harm to Customers as ‘Reckless’ and ‘False’
# 7                     CryptoPunks NFT Fetches Millions: Punk #7804 Sold for Over $16M in ETH
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/156/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df156 = pd.DataFrame({'headline_news':headline_news})
df156
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 156 of 2188 | CryptoPotato</title>
#                                                                                    headline_news
# 0                               Bitcoin (BTC) Price Recovers But Danger Still Looms: QCP Capital
# 1                     Decline in Bitcoin (BTC) Wallets Reflects Market Fear, But There’s A Catch
# 2          These Are the Two Critical Levels for ETH in the Short Term (Ethereum Price Analysis)
# 3  Bitcoin Price Analysis: Is BTC Ready to Explode to a New ATH Following the Recent Correction?
# 4                                    Crypto Price Analysis Mar-21: ETH, XRP, ADA, SHIB, and DOGE
# 5              ETH Is Not a Security: Coinbase Bites Back as SEC Targets The Ethereum Foundation
# 6                                          Ripple (XRP) Price Prediction: Is $1 Coming in April?
# 7                                                    Shiba Inu (SHIB) Burn Rate Explodes by 500%
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/157/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df157 = pd.DataFrame({'headline_news':headline_news})
df157
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 157 of 2188 | CryptoPotato</title>
#                                                                                           headline_news
# 0                                                           Why is the Shiba Inu (SHIB) Price Up Today?
# 1  Important Ripple v SEC Lawsuit Update, Bitcoin (BTC) Price Resurgence, and More: Bits Recap March 21
# 2                           Stacks (STX) Surges 30% to ATH on Upgrade Approval and BTC Yield Incentives
# 3                                    Bitcoin Post-Halving Returns Could Boost BTC Prices 200%: Analysts
# 4               Bitcoin Skyrockets by Over $7K Following Fed’s Latest Meeting, Leaving $320M Liquidated
# 5                Dutch Indictment Alleges Tornado Cash Developer’s Involvement in $1.2B Laundering Case
# 6                             SBF’s Lawyers Fire Back Against DOJ’s Harsh Sentencing Bid of 40-50 Years
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/158/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df158 = pd.DataFrame({'headline_news':headline_news})
df158
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 158 of 2188 | CryptoPotato</title>
#                                                                                    headline_news
# 0                                Bitcoin Spikes 4% After Federal Reserve Maintains Rates At FOMC
# 1                                   Trezor’s X Account Compromised in Potential Swim Swap Attack
# 2             These Altcoins Have Entered Opportunity Zone Buys Amid Bitcoin’s Price Corrections
# 3                                     Ripple (XRP) Price Hits an ATH But It’s Not What You Think
# 4   Will Solana Surge Back Above $200 Soon? Three Things to Watch This Week (SOL Price Analysis)
# 5                                  Bitcoin ETF Outflows Hit New Record Driving BTC Below $61,000
# 6                       Ripple (XRP) Receives Support From This Leading Crypto Exchange: Details
# 7                                          Ripple v. SEC Lawsuit: What’s the Latest Development?
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/159/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df159 = pd.DataFrame({'headline_news':headline_news})
df159
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 159 of 2188 | CryptoPotato</title>
#                                                                                   headline_news
# 0              Spot Ethereum ETFs Will be ‘Ultimately Denied’ Following Latest Delays: Analysts
# 1  Bitcoin Miners’ Reserves Plummet to April 2021 Lows Amid Profit-Taking and BTC Price Decline
# 2                 What Drives Bitcoin’s Price Down, How Low Can it Go as BTC Heads Toward $60K?
# 3        Nigerian Court Orders Binance to Release Comprehensive Data of All Local Users: Report
# 4                           Fidelity Wants to Stake a Portion of Its Proposed Spot Ethereum ETF
# 5                                         Binance Surpasses $100 Billion in User Asset Holdings
# 6                     Binance Founder CZ to Launch Non-Profit Education Project Amid Legal Woes
# 7                   Meme Coin Madness: This Trader Made Over $3 Million in Less Than Three Days
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/160/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df160 = pd.DataFrame({'headline_news':headline_news})
df160
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 160 of 2188 | CryptoPotato</title>
#                                                                            headline_news
# 0                          Cardano Ranks First in This Major Metric: ADA Bull Run Ahead?
# 1                       Important Coinbase Updates Affecting These Two Altcoins: Details
# 2                      Ethereum (ETH) Prices Could Face Heavy Resistance if This Happens
# 3  These Crypto Exchanges Will Support the SLERF Community Following Presale Fund Mishap
# 4             Japan’s $1.5 Trillion GPIF Pension Fund Eyes Bitcoin Amidst Surging Market
# 5                                                    Top 5 Meme Coins to Watch This Week
# 6          Layer-1 MANTRA Secures $11M Investment to Drive Real-World Asset Tokenization
# 7                   Buy the Dip: MicroStrategy Purchases 9,245 BTC for Over $620 Million
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/161/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df161 = pd.DataFrame({'headline_news':headline_news})
df161
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 161 of 2188 | CryptoPotato</title>
#                                                                              headline_news
# 0  Crypto Markets Lose $220 Billion in 2 Days as Bitcoin Slumps Toward $63K (Market Watch)
# 1                           BTC Under $10K? Bitcoin Price Flash Crashed on BitMEX to $8.9K
# 2               This Solana Meme Coin Jumps 70% Daily: Could it Become the Next Sensation?
# 3    Over $400M in Liquidations as BTC Slumps to 13-Day Lows, SHIB and DOGE Plummet by 13%
# 4                     Bitcoin Ordinals NFT Craze: NodeMonkes Sees 53% Surge in Floor Price
# 5             Binance Personnel Cleared of Insider Trading Allegations in BOME Controversy
# 6        Digital Asset Inflows Skyrocket to $2.9B YTD, Shattering 2021 Records: CoinShares
# 7                          Ripple (XRP) Embraced by This US-Based Crypto Exchange: Details
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/162/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df162 = pd.DataFrame({'headline_news':headline_news})
df162
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 162 of 2188 | CryptoPotato</title>
#                                                                                      headline_news
# 0                          Top 3 AI Altcoins to Watch Ahead of the Nvidia GTC Conference This Week
# 1                        What Will Come First for ETH: $3,000 or $4,000? (Ethereum Price Analysis)
# 2                                                          Why is the Solana (SOL) Price Up Today?
# 3                              Standard Chartered Ups Bitcoin Prediction by 50%, $150K by 2024 End
# 4                                  Here’s How Low XRP Can Go if $0.6 Fails (Ripple Price Analysis)
# 5  When Will Bitcoin’s Correction End? Bulls Unsuccessful at Pushing $68K (Bitcoin Price Analysis)
# 6          Is the Shiba Inu Bull Run in Trouble? 3 Things to Watch This Week (SHIB Price Analysis)
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/163/')
print(type(request))
soup = 
BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df163 = pd.DataFrame({'headline_news':headline_news})
df163
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 163 of 2188 | CryptoPotato</title>
#                                                                                   headline_news
# 0                                   Solana (SOL) Flips BNB But These Altcoins Are Outperforming
# 1                            Solana Skyrockets Above $200 as Bitcoin Lags Behind (Market Watch)
# 2        Ripple Price Predictions, Shiba Inu (SHIB) Developments, and More: Bits Recap March 18
# 3                       Shiba Inu (SHIB) Explodes 13% Overnight but Rival Meme Coin Outperforms
# 4                               Will Bitcoin Enter The Danger Zone as Fed Rate Decision Looms ?
# 5                                                US SEC Charges 17 in $300M Crypto Ponzi Scheme
# 6                 Core Scientific Reports Yearly Revenue Decrease in Q4 2023, Net Losses Shrink
# 7      Bitcoin Fog Operator Declared Guilty of Money Laundering, Faces Up to 50 Years in Prison
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/164/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df164 = pd.DataFrame({'headline_news':headline_news})
df164
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 164 of 2188 | CryptoPotato</title>
#                                                                                      headline_news
# 0                      Bitcoin Is a Top 10 Financial Asset by Market Cap, But What About Ethereum?
# 1       Bitcoin Slumps to 10-Day Lows, DOGE and SHIB Among the Double-Digit Losers (Weekend Watch)
# 2                     US Treasury Probes $165M Crypto Transactions Linked to Hamas Support: Report
# 3                      BNB Chain Doubles Down on Layer 2 Expansion With Rollup-as-a-Service (RaaS)
# 4       7RCC’s Spot Bitcoin and Carbon Credit Futures ETF Moves Closer to Reality with NYSE Filing
# 5                                           7 Signals Bitcoin Is Rocking Outside The United States
# 6  BOOK OF MEME (BOME) Enters Top 100 Crypto Assets Days After Launch Following Major Binance News
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/165/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df165 = pd.DataFrame({'headline_news':headline_news})
df165
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 165 of 2188 | CryptoPotato</title>
#                                                                                                headline_news
# 0                                        Binance Labs Quietly Transitions to Independent Entity From Binance
# 1                                               Ethereum L2 TEN Raises $9 Million From Banking Consortium R3
# 2                                        Coinbase Claps Back at Senators Urging Halt on Crypto ETF Approvals
# 3                                   Is MicroStrategy (MSTR) A Better Investment Than Bitcoin? Experts Debate
# 4                            Shiba Inu (SHIB) Might be Gearing up for Another Triple-Digit Rally: Here’s Why
# 5                                      Here’s Why Robert Kiyosaki Prefers Bitcoin Over Gold, Silver, and Oil
# 6                                      XRP Bull Run Paused as Bears Push Toward $0.6 (Ripple Price Analysis)
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/166/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df166 = pd.DataFrame({'headline_news':headline_news})
df166
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 166 of 2188 | CryptoPotato</title>
#                                                                                  headline_news
# 0                           Here’s Why VanEck Thinks Ethereum ETFs Could Outpace Bitcoin Funds
# 1  Here’s How Low ETH Can Go if $3.5K Fails to Hold Selling Pressure (Ethereum Price Analysis)
# 2                                    Major Binanace Announcement Related to the Solana Network
# 3        Here’s How a Trader Turned 50 SOL into $123K in Just 14 Hours with BOME Token Presale
# 4               This New Solana Meme Coin Explodes 5,000% Daily: Could It Become the Next WIF?
# 5          Crypto Markets Lose $250 Billion Overnight as Bitcoin Slumped by $8K (Market Watch)
# 6                     Bitcoin’s Cycle Top Is Near, But a 20% Correction is Necessary: Analysts
# 7                                       Will $2.4B Bitcoin Options Expiry Drive Markets Lower?
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/167/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df167 = pd.DataFrame({'headline_news':headline_news})
df167
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 167 of 2188 | CryptoPotato</title>
#                                                                               headline_news
# 0       Cardano Blockchain Hits ATH in This Important Metric, Can The Price of ADA Keep Up?
# 1             Nigeria Demands Data on Binance’s Top 100 Users Amid Naira Stability Concerns
# 2                     Can’t Happen With Bitcoin: Bakkt Receives Delisting Warning From NYSE
# 3                                  Peter Schiff Admits That He Wishes He Had Bought Bitcoin
# 4                Dogecoin Price Prediction: How Realistic is for DOGE to Hit $1 This Cycle?
# 5  BlackRock’s IBIT Beats Grayscale’s GBTC in This Important Metric Amid BTC ETF Excitement
# 6                              Bitcoin Whales Taking Profits? BTC Price Tumbles Toward $70K
# 7         This Trending Meme Coin Hit a New ATH After Completing a Major Milestone: Details
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/168/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df168 = pd.DataFrame({'headline_news':headline_news})
df168
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 168 of 2188 | CryptoPotato</title>
#                                                                                               headline_news
# 0                                      Massive Ripple Price Prediction: Is XRP About to Outperform Bitcoin?
# 1                          Which Country Realized Most Gains From Crypto Investments in 2023? (Chainalysis)
# 2                                                    Ripple v. SEC Lawsuit Update: What to Expect in March?
# 3                                               Crypto Price Analysis Mar-15: ETH, XRP, ADA, SHIB, and DOGE
# 4                                   Bitcoin (BTC) Price at $100K Is a Matter of When Not If, Says Adam Back
# 5                         Bitcoin Maintains $73K, Solana Skyrockets 14% Daily to 2-Year High (Market Watch)
# 6  Important Shiba Inu (SHIB) Developments, Bitcoin (BTC) Conquers New Peaks, and More: Bits Recap March 14
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/169/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df169 = pd.DataFrame({'headline_news':headline_news})
df169
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 169 of 2188 | CryptoPotato</title>
#                                                                                   headline_news
# 0                                 Coinbase Allows Eligible Users Access to 11 Altcoins: Details
# 1                 Coinbase Mimics MicroStrategy, Announces $1 Billion Convertible Bond Offering
# 2                         MicroStrategy Announces Another $500 Million Note Sale To Buy Bitcoin
# 3     This Meme Coin May be the Best Performer in 2024-2025 and It’s not SHIB or DOGE (Analyst)
# 4                            Former Binance CEO CZ Ordered to Surrender Canadian Passport to US
# 5                Here’s What Financial Advisors Think of The Bitcoin ETFs, According to Bitwise
# 6                                       4 Bitcoin Halving Cycle Protips From Crypto X (Twitter)
# 7                         Is Bitcoin About to Correct or is $75K Imminent? (BTC Price Analysis)
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/170/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df170 = pd.DataFrame({'headline_news':headline_news})
df170
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 170 of 2188 | CryptoPotato</title>
#                                                                                    headline_news
# 0  Bitcoin Price Is Up 1,700% Since the Covid-19 Crash 4 Years Ago Today, What Else Has Changed?
# 1                        Here’s When the Ripple (XRP) Bull Run Might Lead to a New ATH: Analysts
# 2         Spot Bitcoin ETFs Experience Record $1.05 Billion Daily Inflow as BTC Soared Past $73K
# 3            BTC Charts Fresh ATH Above $73K, BNB Nears $600 After 7% Daily Surge (Market Watch)
# 4           Shiba Inu (SHIB) and PEPE Whales Take Profits but Meme Coin Market Remains Resilient
# 5             Bitcoin Price Prediction: What’s the Next Target and is a Liquidity Crisis Coming?
# 6              Important Binance Announcement Affecting Traders of These Shiba Inu (SHIB) Rivals
# 7                                Grayscale Files to Launch More Competitive ‘Bitcoin Mini Trust’
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/171/')
print(type(request))
soup = bs4.BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df171 = pd.DataFrame({'headline_news':headline_news})
df171
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 171 of 2188 | CryptoPotato</title>
#                                                                                  headline_news
# 0             Thai SEC Opens Doors to Private Funds for Spot Bitcoin ETFs, But There’s a Catch
# 1     Daily Bitcoin Miner Revenue Reached New Peak Amid BTC Rally, Exceeding April 2021 Levels
# 2                   Jamie Dimon Says He’ll “Defend Your Right to Buy Bitcoin” After Price Pump
# 3     Altcoin Season Continues Momentum With Focus on Meme Coins as BTC Hits New ATH: Bitfinex
# 4                       Here’s When Bitcoin’s (BTC) Price Will Peak During This Cycle: Experts
# 5  How Is This Bitcoin (BTC) Bull Run Different Than All Previous Ones? (Pre-Halving Analysis)
# 6                                  Halfway to Bitcoin Euphoria, Are Retail Investors Here Yet?
# 7                     Shiba Inu (SHIB) Outperforms Dogecoin (DOGE) in This Key Metric: Details
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/172/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df172 = pd.DataFrame({'headline_news':headline_news})
df172
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 172 of 2188 | CryptoPotato</title>
#                                                                              headline_news
# 0            Bitcoin’s New ‘Millionaire’ Wallets Lag Despite BTC’s All-Time High: Research
# 1  Is the SHIB Bull Run in Danger Following 250% Monthly Gains? (Shiba Inu Price Analysis)
# 2                                                  Why is the Ripple (XRP) Price Up Today?
# 3      XRP, AVAX, TON Explode by Double Digits Daily as BTC Charted New ATH (Market Watch)
# 4                    Grayscale Sees Huge Bitcoin ETF Outflow, But Record Inflow for VanEck
# 5                   Ripple (XRP) Price Prediction: Is $1 Coming Following 15% Daily Surge?
# 6           Discussions for Spot Ethereum ETFs in Hong Kong Underway Amidst Bitcoin Frenzy
# 7      X (Formerly Twitter) Remains a Haven for Scammers as Phishing Incidents Claim $104M
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/173/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df173 = pd.DataFrame({'headline_news':headline_news})
df173
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 173 of 2188 | CryptoPotato</title>
#                                                                               headline_news
# 0    Bitcoin Will Save The World When The U.S. Government Steals Our Money, Predicts Balaji
# 1                       Here’s What Vitalik Buterin Proposes in Case of a Quantum Emergency
# 2                      Solana (SOL) Makes a Comeback: $24M Inflows Signal Positive Momentum
# 3  Ethereum Explodes Past $4,000 as Bulls Now Eye All-Time High Levels (ETH Price Analysis)
# 4                 Ripple Price Analysis: XRP Bull Run Finally Here as Buyers Push to $0.70?
# 5              Viral Solana Meme Coin Dogwifhat (WIF) With Massive Marketing Plans: Details
# 6                           Why Did ARK Invest Sell $150M Coinbase (COIN) Shares in a Week?
# 7       BTC Tops $72K as Bulls Aim Higher, What’s the Next Target? (Bitcoin Price Analysis)
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/174/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df174 = pd.DataFrame({'headline_news':headline_news})
df174
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 174 of 2188 | CryptoPotato</title>
#                                                                                             headline_news
# 0                   MicroStrategy Buys Another 12,000 BTC After Raising Over $800M From Convertible Notes
# 1                                Bitcoin Is Now Bigger Than Silver, Rising to 8th Largest Financial Asset
# 2                 Crypto Markets Add $100 Billion Daily as Bitcoin (BTC) Heads Toward $72K (Market Watch)
# 3                                         Shiba Inu (SHIB) Lands a Spot on a Very Prestigious Forbes List
# 4                                                    Is Optimism Over Spot Ethereum ETF Approvals Waning?
# 5                                                      Bitcoin Explodes to $71K, Charts New All-Time High
# 6  Shiba Inu (SHIB) Metrics Go Wild, Bitcoin (BTC) Jumps to an ATH of $70K, and More: Bits Recap March 11
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/175/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df175 = pd.DataFrame({'headline_news':headline_news})
df175
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 175 of 2188 | CryptoPotato</title>
#                                                                                                      headline_news
# 0                                                                  Crypto Investment Fraud Spiked 53% in 2023: FBI
# 1                    Arthur Hayes Clarifies: Ethena’s Yield Mechanism Unique from Terra’s Collapsed UST Stablecoin
# 2                                           7 Signals the Bitcoin Bull Run Has Room to Run After $70,000 (Opinion)
# 3  Nexo Product Manager Talks 2022 Crypto Lenders’ Crisis and Which Coin Users Seek The Most (Exclusive Interview)
# 4                               The Bitcoin Halving is Getting Near: Miners Need to Prepare, According to Fidelity
# 5                                              This Shiba Inu (SHIB) Competitor Enters the Top 60 Cryptocurrencies
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/176/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df176 = pd.DataFrame({'headline_news':headline_news})
df176
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 176 of 2188 | CryptoPotato</title>
#                                                                                 headline_news
# 0                            Coinbase Says AI Tokens Value ‘Overstated,’ Surge Fueled by Hype
# 1                               Arkham Reveals Tesla and SpaceX’s Bitcoin (BTC) Stash: Report
# 2                           Ethereum’s Dencun Upgrade Set to Drive Near-Zero Transaction Fees
# 3     Bitcoin Accumulation Addresses See Record Inflows as Correction Risk Looms: CryptoQuant
# 4                                     Bitcoin Price Prediction: Can BTC Reach $100K in March?
# 5      Bitcoin Stopped at $70K, FLOKI Skyrockets 111% Weekly and Nears Top 50 (Weekend Watch)
# 6  ChatGPT Analyzes if the Ripple (XRP) Price Can Surpass $1 Before the Bitcoin (BTC) Halving
# 7                       This Is How Shiba Inu (SHIB) Can Become The Largest Meme Coin in 2024
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/177/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df177 = pd.DataFrame({'headline_news':headline_news})
df177
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 177 of 2188 | CryptoPotato</title>
#                                                                                           headline_news
# 0                               Bitcoin Will Likely Reach $250k This Cycle, Says Lead Glassnode Analyst
# 1                           These Catalysts Could Push ETH to $10K or Higher This Year: Bitwise Analyst
# 2                                   US Government to Fight Do Kwon’s Extradition to South Korea: Report
# 3                                            Massive Bitcoin Rollecoaster as BTC Price Taps $70,000 ATH
# 4                                               Important Binance Update Affecting Ripple (XRP) Traders
# 5                                 Ripple Close to a Huge Adoption Milestone: Will the XRP Price Follow?
# 6  Bitcoin Flirts With ATH as Dog Meme Coins like Shiba Inu Take Center Stage: This Week’s Crypto Recap
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/178/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df178 = pd.DataFrame({'headline_news':headline_news})
df178
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 178 of 2188 | CryptoPotato</title>
#                                                                            headline_news
# 0                       Massively Anticipated Airdrop on Solana Faces Community Backlash
# 1     Bitcoin Price Prediction: Explosion Above $69K Incoming or a New Correction First?
# 2                    BlackRock Wants to Buy Spot Bitcoin ETFs for Global Allocation Fund
# 3                               Crypto Price Analysis Mar-8: ETH, XRP, ADA, SOL, and BNB
# 4            Shiba Inu (SHIB) Bull Run Continues as This Important Metric Soars by 2000%
# 5       Binance Coin (BNB) Soars to 2-Year High, Ethereum (ETH) Nears $4K (Market Watch)
# 6                      Will Markets Surge With a $3 Billion Crypto Options Expiry Event?
# 7  Solana Sees Explosive Growth in DEX Trading Volume, Surpasses $2B Mark Multiple Times
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/179/')
print(type(request))
soup = bs4.BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df179 = pd.DataFrame({'headline_news':headline_news})
df179
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 179 of 2188 | CryptoPotato</title>
#                                                                            headline_news
# 0                                Is Ethereum (ETH) a Security? SEC Chair Still Won’t Say
# 1        Bitcoin Miners Earned $75.9 Million in Daily Revenue, Second-Highest in History
# 2                     Reasons Why Fetch.AI’s FET Token Soared 360% and Hit All-Time High
# 3                         South Korean Police Request Aid in Extraditing Do Kwon: Report
# 4             Ripple (XRP) Lags Behind 64% of Top 100 Cryptocurrencies: Bounce Incoming?
# 5            Michael Saylor Thinks Bitcoin ETFs Will Outshine Gold, Compete with S&P 500
# 6                  Robert Kiyosaki Predicts Bitcoin (BTC) Price to Hit $300K by 2024 End
# 7  Bitcoin Kimchi Premium in South Korea Soars to 2-Year High, Is That Bad News for BTC?
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/180/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df180 = pd.DataFrame({'headline_news':headline_news})
df180
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 180 of 2188 | CryptoPotato</title>
#                                                                                                   headline_news
# 0                            Bitcoin Supply Distribution Begins But Sustained Bull Market to Continue: Analysis
# 1  Bitcoin (BTC) Price Volatility, Shiba Inu (SHIB) Advancements, Cardano (ADA) Predictions: Bits Recap March 7
# 2                                                    SEC Requests Court Intervenes in Binance Discovery Process
# 3                             Binance.US Hit by Layoffs and 75% Revenue Drop Amid SEC Lawsuit Aftermath: Report
# 4                                                WOOFi Reports $8.75 Million Loss, Offers 10% Bounty for Return
# 5                             Speculative Trades Flushed Out as Bitcoin, Ethereum, Solana’s Open Interest Drops
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/181/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df181 = pd.DataFrame({'headline_news':headline_news})
df181
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 181 of 2188 | CryptoPotato</title>
#                                                                                  headline_news
# 0         DCG, Barry Silbert Move to Dismiss NYAG Lawsuit, Label Claims as ‘Baseless Innuendo’
# 1                    Shiba Inu Price Analysis: SHIB Explodes 228% Weekly as Bulls Take Control
# 2  Here’s Why Bitcoin’s (BTC) Correction is Very Beneficial for Market Positivity: CryptoQuant
# 3                          Bitcoin (BTC) Price to Exceed $200K by June 2024 If History Repeats
# 4                      Major Binance Announcement Concerning Solana (SOL) Withdrawals: Details
# 5                 SHIB Madness: How This Shiba Inu Trader Turned $2,500 Into Over $1.5 Million
# 6                              Investors Prefer Bitcoin ETFs Over Gold as Both Assets Hit ATHs
# 7        ETH Charts 2-Year Peak, BTC Calms After Rollercoaster Ride and New ATH (Market Watch)
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/182/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df182 = pd.DataFrame({'headline_news':headline_news})
df182
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 182 of 2188 | CryptoPotato</title>
#                                                                            headline_news
# 0                                 New Bitcoin ETFs Hit $10B in Record Trading Volume Day
# 1             These Important Shiba Inu (SHIB) Metrics Skyrocket Amid Massive Volatility
# 2  Bitcoin Sees Record Open Interest in Futures Markets Ahead of BTC’s New ATH: Bitfinex
# 3               Binance Halts Nigerian Naira Transactions, Compliance Concerns Intensify
# 4                      SEC Delays Spot Ethereum ETF Decision From BlackRock and Fidelity
# 5                More Pain: Over $1 Billion of Liquidations as Bitcoin Slides to $61,000
# 6  Pro-Ripple (XRP) Lawyer Running for US Senate Receives Support From Cardano’s Founder
# 7       Fantom Secures Court Order Against Multichain to Recoup Lost Assets from Exploit
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/183/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df183 = pd.DataFrame({'headline_news':headline_news})
df183
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 183 of 2188 | CryptoPotato</title>
#                                                                                headline_news
# 0                                   Do Kwon’s Extradition to the US Revoked Following Appeal
# 1               Top Cardano (ADA) Price Predictions: Is a 1,200% Incoming in the Short Term?
# 2          Bitcoin Plummets Back to $65,000 After New ATH, Over $670 Million In Liquidations
# 3                    These Crypto Heavyweights Just Onboarded Bitcoin’s Stacks (STX) Network
# 4                   History: Bitcoin Breaks New All-Time High Of $69,000 Well Before Halving
# 5                       Two Years Later: CryptoPunks NFT Collection Records Another Big Sale
# 6                                            Two Reasons Bitcoin Investors Buy Into Strength
# 7                         Bitcoin is the Ultimate Bubble: Peter Schiff Resumes Bashing Spree
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/184/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df184 = pd.DataFrame({'headline_news':headline_news})
df184
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 184 of 2188 | CryptoPotato</title>
#                                                                                 headline_news
# 0                  Shiba Inu (SHIB) Hits a Major Milestone as the Price Explodes 50% in a Day
# 1  Is XRP on the Verge of Exploding to $1? Analysts with Interesting Ripple Price Predictions
# 2                          MicroStrategy Will Offer $600M in Convertible Notes to Buy Bitcoin
# 3                   Are The Rising Bitcoin ETF Volumes The Reason Behind BTC’s Surge to $68K?
# 4           Bitcoin Price Prediction: BTC to Reach $170K This Cycle but Is That Conservative?
# 5              Bitcoin (BTC) Comes Close to ATH of $69K, Leaving $550 Million in Liquidations
# 6                                                 Why the SEC Might Not Approve Ethereum ETFs
# 7                  Bloomberg Expert Says Ethereum ETF Approvals Are Overhyped Next To Bitcoin
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/185/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df185 = pd.DataFrame({'headline_news':headline_news})
df185
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 185 of 2188 | CryptoPotato</title>
#                                                                                                   headline_news
# 0                                                         WSJ Parent Company Sued Over Tether, Bitfinex Article
# 1                                                               Important Binance Update Affecting PEPE Traders
# 2                                                    Tether (USDT) Records New Milestone, Hits $100B Market Cap
# 3              Bitcoin (BTC) Price Hits New All-Time High Against Euro and British Pound Following Latest Surge
# 4                   Will ETH Reach $4K This Week or Are Bears Preparing a Correction? (Ethereum Price Analysis)
# 5                       Traders Anticipate an XRP Bull Run Following the Surge to $0.65 (Ripple Price Analysis)
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/186/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df186 = pd.DataFrame({'headline_news':headline_news})
df186
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 186 of 2188 | CryptoPotato</title>
#                                                                                headline_news
# 0                                                Why is the Shiba Inu (SHIB) Price Up Today?
# 1                            Forget Shiba Inu: Electric Capital Says Polkadot Is Hot in 2024
# 2  Energy Trading Platform SunContract Introduces First NFT-Powered Solar Panels Marketplace
# 3                  Meme Coin Madness: These Popular Meme Coins Explode to New All-Time Highs
# 4           Bitcoin Jumps Past $65K, Shiba Inu and Dogecoin Soar by 25% Daily (Market Watch)
# 5     Bitcoin (BTC) Bull Run, Shiba Inu (SHIB) Price Explosion, and More: Bits Recap March 4
# 6                      Will Shiba Inu (SHIB) Become the Largest Meme Coin During This Cycle?
# 7                              Senators in the US Introduce Bill to Halt Biden’s CBDC Agenda
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/187/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df187 = pd.DataFrame({'headline_news':headline_news})
df187
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 187 of 2188 | CryptoPotato</title>
#                                                                                      headline_news
# 0                         Spot Bitcoin ETFs May Offer Stability Amidst Unsustainable Funding Rates
# 1                              Ripple (XRP) Price Poised for a Massive Breakout in March: Analysts
# 2                                Bitcoin and Ether Dominate Institutional Portfolios: Bybit Report
# 3                 These Indicators Are Signaling a Possible Correction in BTC’s Price: CryptoQuant
# 4    Top Meme Coins WIF, PEPE, SHIB, FLOKI, and BONK Skyrocket Triple Digits Weekly (Market Watch)
# 5                Why Did Shiba Inu Explode 130% Weekly, How Far Up Can SHIB Go? Perplexity Answers
# 6  Shiba Inu (SHIB) Price Explodes 130% in a Week: Here’s How Many Holders are Currently in Profit
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/188/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df188 = pd.DataFrame({'headline_news':headline_news})
df188
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 188 of 2188 | CryptoPotato</title>
#                                                                                       headline_news
# 0             Is BTC Overdue a Correction Following Epic Rally Above $60K? (Bitcoin Price Analysis)
# 1                                                  Shiba Inu (SHIB) Burn Rate Skyrockets by 30,000%
# 2                                          Shiba Inu Price Predictions as SHIB Explodes 100% Weekly
# 3                    Got Bitcoin? Another US Bank Shows Signs of Weakness After Acquiring Signature
# 4                           Here’s What to Expect in March After Bitcoin’s Rally to $64K: Santiment
# 5  Shiba Inu (SHIB) Explodes 65% Daily, Dogecoin (DOGE) Follows Suit With 20% Surge (Weekend Watch)
# 6             MicroStrategy (MSTR) Stock Skyrockets Above $1,000, Dwarfs S&P 500, Nasdaq, Dow Jones
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/189/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df189 = pd.DataFrame({'headline_news':headline_news})
df189
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 189 of 2188 | CryptoPotato</title>
#                                                                                         headline_news
# 0                                          Bitcoin Set for 10 Months Of Face Melting FOMO, Says PlanB
# 1               Bitcoin With a Monster Monthly Candle, Solana Explodes, Memes Soar: This Week’s Recap
# 2                   Entering Top 150 ETFs: BlackRock’s IBIT Bitcoin Fund Surpasses $10 Billion in AUM
# 3                                            Crypto Price Analysis Mar-1: ETH, XRP, ADA, SOL, and BNB
# 4                      Bitcoin (BTC) Addresses in Loss Plumment to Historic Loss; But There’s a Catch
# 5                                  AI Coins Chart Massive Returns in 2024, How Do Meme Coins Compare?
# 6                                          Elon Musk Sues OpenAI and its CEO, Worldcoin (WLD) Dips 5%
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/190/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df190 = pd.DataFrame({'headline_news':headline_news})
df190
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 190 of 2188 | CryptoPotato</title>
#                                                                         headline_news
# 0                Ethereum Price Prediction: Is ETH Headed for $5,000 in the Mid Term?
# 1             Meme Coins Battle: Whales Are Ditching PEPE And Accumulating BONK, SHIB
# 2                        How Will Crypto Markets React to $2B Bitcoin Options Expiry?
# 3            This Is Why Michael Saylor’s Fortune Skyrocketed by $700 Million in Days
# 4         Reversal: Merrill Lynch, Wells Fargo Begin Offering Bitcoin ETFs To Clients
# 5                                    Seneca Recovers 80% of Funds After $6.4M Exploit
# 6            We Asked ChatGPT if Pepe Coin (PEPE) Could Flip Shiba Inu (SHIB) in 2024
# 7  Gemini Settles With New York DFS, Commits to Return $1.1 Billion to Earn Customers
# 8      Terraform Labs Faces SEC Scrutiny Over Suspicious $166 Million Payment: Report
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/191/')
print(type(request))
soup = bs4.BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df191 = pd.DataFrame({'headline_news':headline_news})
df191
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 191 of 2188 | CryptoPotato</title>
#                                                                         headline_news
# 0             Here’s Why the Shido Token Crashed 94% Despite the Ongoing Market Rally
# 1                MicroStrategy’s Bitcoin Bet Is Paying Off Big, Delivering 2x Returns
# 2             Ethereum Tests $3.5K as Traders Set Higher Targets (ETH Price Analysis)
# 3  XRP on the Verge of a Massive Breakout as Bulls Test $0.6? (Ripple Price Analysis)
# 4               Is BTC About to Skyrocket to $69K This Week? (Bitcoin Price Analysis)
# 5        Long-Awaited Airdrop Update Benefiting Certain Ripple (XRP) Holders: Details
# 6            Chainalysis Data Reveals 93% Drop in Tornado Cash Inflows Post-Sanctions
# 7                      Experts Predict Imminent Altseason as Bitcoin Holds Above $62K
# 8                                  The Reasons Behind the Shiba Inu (SHIB) 25% Surge?
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/192/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df192 = pd.DataFrame({'headline_news':headline_news})
df192
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 192 of 2188 | CryptoPotato</title>
#                                                                                      headline_news
# 0                                                          Why is the Solana (SOL) Price Up Today?
# 1           Shiba Inu (SHIB) Bull Run, Important Ripple v. SEC Update, and More: Bits Recap Feb 29
# 2       Bitcoin’s Rollercoaster Above $60K, Dogecoin and Shiba Inu Skyrocket by 30% (Market Watch)
# 3  Coinbase Recovering From Outage After Users Report Zero Balances and Millions in Crypto Missing
# 4                                                Pepe Explodes 180% Weekly, Leads Meme Coin Frenzy
# 5                                   Uniswap Introduces New Features to Improve Swapping Experience
# 6                                          Chamber of Digital Commerce Backs Kraken in SEC Lawsuit
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/193/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df193 = pd.DataFrame({'headline_news':headline_news})
df193
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 193 of 2188 | CryptoPotato</title>
#                                                                     headline_news
# 0          3 Catalysts That Suggest More Gains for Bitcoin After Price Broke $60K
# 1       Shiba Inu Brings Privacy To SHIB Holders Through New Encryption Standards
# 2  BTC Rejected Off $64,000 As Crypto Market Suffers $600 Million Of Liquidations
# 3   BlackRock Bitcoin ETF Smashes Daily Inflow Record, Ranks 2nd In United States
# 4                                COTI’s $100M Growth Fund: Announcing Focus Areas
# 5       Bitcoin Enters Top 10 Assets by Market Cap, Surpasses Buffett’s Berkshire
# 6                                  The Reason Toncoin (TON) Price Exploded by 25%
# 7            Bitcoin (BTC) Price Hits $60K for the First Time Since November 2021
# 8      Crypto Investor Greed Soars to November 2021 Highs as Bitcoin Crosses $59K
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/194/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df194 = pd.DataFrame({'headline_news':headline_news})
df194
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 194 of 2188 | CryptoPotato</title>
#                                                                   headline_news
# 0      Massive Increase in Important Shiba Inu Metrics: SHIB Bull Run Imminent?
# 1       This Is the Prison Sentence Requested by Sam Bankman-Fried’s Legal Team
# 2                Ripple v. SEC Lawsuit Update: SEC Requests Deadline Extensions
# 3             Bitcoin Soars Past $59K, PEPE Skyrockets 40% Daily (Market Watch)
# 4         Three Cryptocurrencies Under $1 Worth Watching After Bitcoin Hit $59K
# 5  Solana Meme Coin WIF Explodes to a New ATH After 100% Monthly Surge: Details
# 6        Bitcoin Supply in Profit Ratio Surges Close to Bull Market Peak Levels
# 7    Terraform Labs Co-Founder Do Kwon to Miss First US SEC Fraud Trial: Report
# 8        Blast Network’s Layer 2 Project Loses Over $1.2M in Suspected Rug Pull
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/195/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df195 = pd.DataFrame({'headline_news':headline_news})
df195
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 195 of 2188 | CryptoPotato</title>
#                                                                                    headline_news
# 0                   Tornado Cash Vulnerability: Developers Flag Deposits’ Risk Since January 1st
# 1                              This Cryptocurrency Shoots 20% as Coinbase Prepares for a Listing
# 2                                                    HTX Withdraws Hong Kong License Application
# 3                     Bitcoin Price Predictions: From $150K and $200K to a Whopping $21M Per BTC
# 4                           Ethereum’s Layer 2 TVL Nears $30 Billion as ETH-Related Tokens Surge
# 5               Peter Brandt Predicts $200,000 Bitcoin (BTC) Peak by 2025 After Channel Breakout
# 6                   Spot Ethereum ETF in May and Bitcoin Price at $88K by 2024’s End? (Research)
# 7                                                   Solana User Gears Up for Another Big Airdrop
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/196/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df196 = pd.DataFrame({'headline_news':headline_news})
df196
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 196 of 2188 | CryptoPotato</title>
#                                                                                         headline_news
# 0                                        9 Spot Bitcoin ETFs Reached New Peak in Daily Trading Volume
# 1  Bull Market Things: How This Trader Turned $310 Into Almost $1.5 Million Trading Solana Meme Coins
# 2                     Here’s Why The Crypto Market May Be at the Onset of an Altcoin Season: Bitfinex
# 3                                                         Why is the Shiba Inu (SHIB) Price Up Today?
# 4                               SOL Breaks Above $110 but How High Can It Go? (Solana Price Analysis)
# 5         The Reasons Behind Bitcoin’s Surge to $57K and is a God Candle Coming? (BTC Price Analysis)
# 6                     Crypto Markets Add $140 Billion Daily as Bitcoin Price Soars 10% (Market Watch)
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/197/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df197 = pd.DataFrame({'headline_news':headline_news})
df197
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 197 of 2188 | CryptoPotato</title>
#                                                                                  headline_news
# 0                                                      Why is the Ripple (XRP) Price Up Today?
# 1                                  Its Been a Blast: TVL Tops $2 Billion as Mainnet Approaches
# 2                           3 Things to Look in Ethereum After the ETH Price Broke Above $3.2K
# 3                                       Bitcoin Topped $57K, Ethereum Surpasses $3.2K: Details
# 4           Will the SEC Mirror Bitcoin’s ETF Approval Timeline for Ethereum? Experts Weigh In
# 5                     Solana Investor Sentiment Remains Battered With $3M Outflows: CoinShares
# 6                         This Shiba Inu Metric Soars Nearly 15%: Could the SHIB Price Follow?
# 7                                          This Crypto Exchange Went Dark After $56.5M Outflow
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/198/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df198 = pd.DataFrame({'headline_news':headline_news})
df198
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 198 of 2188 | CryptoPotato</title>
#                                                                                              headline_news
# 0  Following ETH’s Recent Explosion Above $3K, This is the Next Important Target (Ethereum Price Analysis)
# 1                 BTC Dropping to $48K or Pushing to $55K: Which One Comes First? (Bitcoin Price Analysis)
# 2               Ripple Seems Primed for a Drop to $0.5, But Will the Bulls Retaliate? (XRP Price Analysis)
# 3                                      Spot Bitcoin ETFs’ Momentum Stalls: Inflows Dip Despite Prior Surge
# 4                                   MicroStrategy With Another Huge Bitcoin Buy: Scoops 3000 BTC at $51.8K
# 5                            Ethereum Whales Withdraw $64.2M in 6 Days Ahead of ETH’s Rally to 2-Year High
# 6                      Important Binance Announcement for February 28th: Fifteen Cryptocurrencies Affected
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/199/')
print(type(request))
soup = bs4.BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df199 = pd.DataFrame({'headline_news':headline_news})
df199
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 199 of 2188 | CryptoPotato</title>
#                                                                                             headline_news
# 0                                                    Ethereum Hits 22-Month High, Where Will ETH Go Next?
# 1  Ethereum (ETH) Price Rally, Ripple (XRP) Predictions, Shiba Inu (SHIB) Developments: Bits Recap Feb 26
# 2                        Hackers Gain Access to MicroStrategy’s X Account, Steal $440k With Phishing Scam
# 3                     OFAC Flags 10 Wallet Addresses Linked to LockBit Affiliates in Ransomware Crackdown
# 4                                Dogecoin (DOGE) Price Echoes of 2020 Surge Emerge Amid Familiar Patterns
# 5                                             US Spot Bitcoin ETFs Surpass $50B Cumulative Trading Volume
# 6                                  Solana NFT Sales Reached Massive Milestone as SOL Price Stalls at $100
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/200/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df200 = pd.DataFrame({'headline_news':headline_news})
df200
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 200 of 2188 | CryptoPotato</title>
#                                                                                       headline_news
# 0                  Is Polygon (MATIC) Price About to Explode by 90%? This Popular Analyst Weighs in
# 1                      Ethereum (ETH) Reclaims $3K Level as Bitcoin (BTC) Eyes $52K (Weekend Watch)
# 2                                                 This Privacy Coin Explodes 30% in a Week: Details
# 3                                                      Tron Fee Revenue Hits ATH $1.758M High: Data
# 4                                          Despite Bitcoin’s Soaring Success, Critics Still Lurking
# 5        Is Bitcoin About to Plummet Toward $50K or is Another Rally Incoming? (BTC Price Analysis)
# 6                    Bitcoin Profits: Jack Dorsey’s Block Reports 90% Surge in BTC Gains in Q4 2023
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/201/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df201 = pd.DataFrame({'headline_news':headline_news})
df201
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 201 of 2188 | CryptoPotato</title>
#                                                                         headline_news
# 0              Massive Shiba Inu (SHIB) Price Prediction for the Immediate Short Term
# 1                          Important Binance Update Affecting SOL, ETH, and FIL Users
# 2                      Unseen Satoshi Nakamoto Emails Revealed, What Do They Tell Us?
# 3                     Uniswap Skyrockets 80% as Bitcoin Stalls at $51K (Market Watch)
# 4                    Ripple (XRP) More Popular Than Ethereum in These Countries: Data
# 5             Cryptocurrency Crimes in Hong Kong Almost Tripled Over the Last 3 Years
# 6        StarkWare Adapts New Token Release Structure Amid Concerns: What’s Changing?
# 7                                               Kraken Moves to Dismiss SEC’s Lawsuit
# 8                                  U-Turn? Donald Trump Says He Can Live With Bitcoin
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/202/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df202 = pd.DataFrame({'headline_news':headline_news})
df202
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 202 of 2188 | CryptoPotato</title>
#                                                                                         headline_news
# 0  Bitcoin Bulls Regroup as Ethereum and Binance Coin Take the Center Stage: This Week’s Crypto Recap
# 1                                           Uniswap (UNI) Explodes 50% Minutes After a Major Proposal
# 2                             FTX Cleared to Sell Shares in Artificial Intelligence Startup Anthropic
# 3                                           Crypto Price Analysis Feb-23: ETH, XRP, ADA, SOL, and BNB
# 4                                                            Avalanche is Down: AVAX Price is Dipping
# 5                                          Possible Reasons Behind the Binance Coin (BNB) Price Rally
# 6                                         Ronin Co-founder Zirlin Claims he Lost $9.7M to Wallet Hack
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/203/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df203 = pd.DataFrame({'headline_news':headline_news})
df203
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/204/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df204 = pd.DataFrame({'headline_news':headline_news})
df204
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 204 of 2188 | CryptoPotato</title>
#                                                                                       headline_news
# 0                           Massive Bitcoin Price Prediction by Pantera but BTC Maxis Won’t Like It
# 1                                                                  Top 3 Altcoins to Watch in March
# 2                                   This Cryptocurrency Spikes 20% After Coinbase Announces Support
# 3                                                      Greg Solano Set to Lead Yuga Labs as New CEO
# 4                                                         Why is the Ethereum (ETH) Price Up Today?
# 5                The Race for Ethereum ETFs: Coinbase Urges SEC to Greenlight Grayscale Application
# 6                           Ethereum Surges Past $3K as Bitcoin Recovers Toward $52K (Market Watch)
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/205/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df205 = pd.DataFrame({'headline_news':headline_news})
df205
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 205 of 2188 | CryptoPotato</title>
#                                                                                  headline_news
# 0                                  Michael Saylor Says He Will Buy Bitcoin Forever, Here’s Why
# 1                      Fairshake Super PAC Receives $4.9 Million Funding from Winklevoss Twins
# 2        Coinbase International Exchange Tops $1B Daily Volume While Bitcoin ETF Volumes Surge
# 3                                       Arthur Hayes Says Cardano Is A ‘Shitcoin’ – Here’s Why
# 4                 Montenegro Court Approves Do Kwon’s Extradition to the United States: Report
# 5                                     Ripple CEO Says Firm is Open to Welcoming a Spot XRP ETF
# 6                                Long-Term Bitcoin Holders Shed 200k BTC: Here’s What It Means
# 7  Binance Is Not Responsible for the Steep Decline of the Nigerian Naira, Company Fights Back
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/206/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df206 = pd.DataFrame({'headline_news':headline_news})
df206
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 206 of 2188 | CryptoPotato</title>
#                                                                                            headline_news
# 0                                           7 Best Avalanche (AVAX) Wallets: The Complete Guide for 2024
# 1  Pro-Ripple (XRP) Lawyer John Deaton v. Crypto Critic Elizabeth Warren in The Battle for Massachusetts
# 2                                 What Is Happening With the VanEck Bitcoin ETF? Trading Volume Explodes
# 3       Bitcoin (BTC) Price Rejected at $53K, Leaving Almost $300 Million in Liquidations (Market Watch)
# 4                                     USDC Minting on TRON Ceases, All Support to Be Withdrawn Next Year
# 5                                               Ripple Inks an Important Deal With a Major Bank: Details
# 6                                UK May Introduce Stablecoin and Staking Regulations in 6 Months: Report
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/207/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df207 = pd.DataFrame({'headline_news':headline_news})
df207
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 207 of 2188 | CryptoPotato</title>
#                                                                                headline_news
# 0                  Autoglyphs Set Fetches Record-Breaking $14.6 Million in Historic NFT Sale
# 1                               Shiba Inu (SHIB) Achieves Another Massive Milestone: Details
# 2                               3AC’s Investment in Worldcoin Seems to Pay Off for Creditors
# 3                         Bitcoin ETFs Show Steady Demand as BTC Hits New YTD High: Bitfinex
# 4              Spot Bitcoin ETFs Take Center Stage in South Korean Election Campaign: Report
# 5                      $1 Billion in Bitcoin Withdrawn From Coinbase, Bullish for BTC Price?
# 6  $200M in Liquidations as Ethereum (ETH) Jumps to $3K for the First Time in Almost 2 Years
# 7                COTI Successfully Deploys Garbled Circuits on Blockchain Ahead of V2 Launch
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/208/')
print(type(request))
soup = bs4.BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df208 = pd.DataFrame({'headline_news':headline_news})
df208
# Out:
# <class 'requests.models.Response'>
# None
# Empty DataFrame
# Columns: [headline_news]
# Index: []

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/209/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df209 = pd.DataFrame({'headline_news':headline_news})
df209
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 209 of 2188 | CryptoPotato</title>
#                                                                                        headline_news
# 0               Vitalik Buterin Anticipates Ethereum’s Verkle Trees Upgrade, Hints at AI Integration
# 1                                             Here’s How a Trader Made 1,280x Profit with SORA Token
# 2                        Massive XRP Move Incoming Following 7% Weekly Push? (Ripple Price Analysis)
# 3                   Ethereum Explodes Toward $3K: Two Things to Watch This Week (ETH Price Analysis)
# 4                      Grayscale’s GBTC Outflows Hit $7B Amidst Recovery, But ‘Bleeding’ to Continue
# 5  Can BTC Bulls Continue the Rally Above $52K or is a Correction Imminent? (Bitcoin Price Analysis)
# 6                              Important Binance Announcement Affecting Controversial Ethereum Pairs
# ...

# %%
request = requests.get('https://cryptopotato.com/category/crypto-news/page/211/')
print(type(request))
soup = BeautifulSoup(request.text, 'html.parser')
print(soup.title)
anc = soup.find_all('h3')
anc

headline_news = []
for headline in anc:
    if headline.get_text().strip():  # Check if the tag contains text
        headline_news.append(headline.get_text().strip())
        
df210 = pd.DataFrame({'headline_news':headline_news})
df210
# Out:
# <class 'requests.models.Response'>
# <title>Crypto News Archives | Page 211 of 2188 | CryptoPotato</title>
#                                                                                 headline_news
# 0  Is BTC’s Price Impacted by the Recently-Approved Spot Bitcoin ETFs? (CryptoQuant Analysis)
# 1           Cardano (ADA) Soars 9% Daily While Bitcoin (BTC) Nears $52K Again (Weekend Watch)
# 2                  Solana-Based Meme Coin WIF Explodes 16% Daily as SOL Price Challenges $110
# 3                           These Altcoins Might Outperform Bitcoin (BTC) in 2024: Perplexity
# 4               Mondelēz International Partners With Hedera on Distributed Ledger Technology
# 5                        Stacks Skyrockets 3,028% in Annual Revenue Ahead of Nakamoto Upgrade
# 6    Federal Officer Faces Charges for Allegedly Stealing Crypto Associated With Drug Fortune
# 7                                  Bitcoin Tumbles Below $51K as Daily Liquidations Top $100M
# ...

# %%
news_df = pd.concat([news_df,df101,df102,df103,df104,df105,df106,df107,df108,df109,df110,
                    df111,df112,df113,df114,df115,df116,df117,df118,df119,df120,
                    df121,df122,df123,df124,df125,df126,df127,df128,df129,df130,
                    df131,df132,df133,df134,df135,df136,df137,df138,df139,df140,
                    df141,df142,df143,df144,df145,df146,df147,df148,df149,df150,
                    df151,df152,df153,df154,df155,df156,df157,df158,df159,df160,
                    df161,df162,df163,df164,df165,df166,df167,df168,df169,df170,
                    df171,df172,df173,df174,df175,df176,df177,df178,df179,df180,
                    df181,df182,df183,df184,df185,df186,df187,df188,df189,df190,
                    df191,df192,df193,df194,df195,df196,df197,df198,df199,df200,
                    df201,df202,df203,df204,df205,df206,df207,df208,df209,df210],
                   axis = 0)
news_df
# Out:
#                                                                                headline_news
# 0                                       Bitcoin miner Marathon Digital is mining Kaspa (KAS)
# 1                               Cryptocurrencies waver as focus shifts to BitBot token claim
# 2                               Cryptocurrencies waver as focus shifts to BitBot token claim
# 3                           US government transfers 3,940 BTC worth $241 million to Coinbase
# 4             German’s BKA transfers more Bitcoin to exchanges including Kraken and Bitstamp
# ..                                                                                       ...
# 5                       Stacks Skyrockets 3,028% in Annual Revenue Ahead of Nakamoto Upgrade
# 6   Federal Officer Faces Charges for Allegedly Stealing Crypto Associated With Drug Fortune
# 7                                 Bitcoin Tumbles Below $51K as Daily Liquidations Top $100M
# ...

# %%
news_df = news_df.reset_index(drop=True)
news_df
# Out:
#                                                                                  headline_news
# 0                                         Bitcoin miner Marathon Digital is mining Kaspa (KAS)
# 1                                 Cryptocurrencies waver as focus shifts to BitBot token claim
# 2                                 Cryptocurrencies waver as focus shifts to BitBot token claim
# 3                             US government transfers 3,940 BTC worth $241 million to Coinbase
# 4               German’s BKA transfers more Bitcoin to exchanges including Kraken and Bitstamp
# ...                                                                                        ...
# 2208                      Stacks Skyrockets 3,028% in Annual Revenue Ahead of Nakamoto Upgrade
# 2209  Federal Officer Faces Charges for Allegedly Stealing Crypto Associated With Drug Fortune
# 2210                                Bitcoin Tumbles Below $51K as Daily Liquidations Top $100M
# ...

# %% [markdown]
# ### 2060 news were scraped from cryptopotato.com

# %%
news_df[news_df.duplicated()]
# Out:
#                                                                        headline_news
# 2                       Cryptocurrencies waver as focus shifts to BitBot token claim
# 32                         Missed Pepe and Book of Meme? SolJu could be the next hit
# 194            BTC Tanks to $61K as Long-Awaited Mt. Gox Repayments to Begin in July
# 219                        Bitcoin (BTC) vs. Ethereum (ETH): Which Will Win Q3 2024?
# 293   Financial Advisors Wary of Investing in Spot Bitcoin ETFs, BlackRock Exec Says
# 378                                    Why is the Shiba Inu (SHIB) Price Down Today?
# 953                                    Top Ripple (XRP) Price Predictions as of Late
# 979                          Polkadot (DOT) Ecosystem Recap: The Latest Developments
# 1123       Meme Coin Bull Market: BONK, WIF, PEPE, and Others Spike by Double Digits
# 1240                                     Why is the Shiba Inu (SHIB) Price Up Today?
# ...

# %%
main_df = news_df.drop_duplicates()

# %%
main_df
# Out:
#                                                                                                                      headline_news
# 0                                                                                                               Latest Crypto News
# 1                                                                Self-custodial Bitcoin staking protocol Babylon announces mainnet
# 2                                                                AC Milan inks new sponsorship deal with crypto exchange, Bitpanda
# 3                                                                        Bitwise expands into Europe with acquisition of ETC Group
# 4                                                                    Binance to support Frontier (FRONT) token swap and rebranding
# ..                                                                                                                             ...
# ...

# %%
add_headline = pd.read_csv('extracted_headlines2.csv')
add_headline
# Out:
#                                                                                    headline_news
# 0    theres definitely a political shift related to crypto vanecks digital assets research chief
# 1                             secs gary gensler could take time for spot ether etfs crypto world
# 2                                       bitcoin crosses 70000 more spot etfs launch crypto world
# 3                     were targeting wealth managers with spot bitcoin etf wisdomtrees will peck
# 4      bitcoin jumps back above 69000 dc settles michael saylor tax fraud case cnbc crypto world
# ..                                                                                           ...
# 146   bitcoin briefly falls below 39000 as post etf selling pressure continues cnbc crypto world
# 147             goldman sachs digital assets chief explains banks participation bitcoin etf boom
# 148                       core scientific hits nasdaq as wall street goes big in bitcoin mining
# ...

# %%
all_df = pd.concat([main_df,add_headline],
                   axis = 0)
all_df
# Out:
#                                                                                   headline_news
# 0                                                                            Latest Crypto News
# 1                             Self-custodial Bitcoin staking protocol Babylon announces mainnet
# 2                             AC Milan inks new sponsorship deal with crypto exchange, Bitpanda
# 3                                     Bitwise expands into Europe with acquisition of ETC Group
# 4                                 Binance to support Frontier (FRONT) token swap and rebranding
# ..                                                                                          ...
# 146  bitcoin briefly falls below 39000 as post etf selling pressure continues cnbc crypto world
# 147            goldman sachs digital assets chief explains banks participation bitcoin etf boom
# 148                      core scientific hits nasdaq as wall street goes big in bitcoin mining
# ...

# %%
all_df = all_df.reset_index(drop=True)
all_df
# Out:
#                                                                                   headline_news
# 0                                                                            Latest Crypto News
# 1                             Self-custodial Bitcoin staking protocol Babylon announces mainnet
# 2                             AC Milan inks new sponsorship deal with crypto exchange, Bitpanda
# 3                                     Bitwise expands into Europe with acquisition of ETC Group
# 4                                 Binance to support Frontier (FRONT) token swap and rebranding
# ..                                                                                          ...
# 902  bitcoin briefly falls below 39000 as post etf selling pressure continues cnbc crypto world
# 903            goldman sachs digital assets chief explains banks participation bitcoin etf boom
# 904                      core scientific hits nasdaq as wall street goes big in bitcoin mining
# ...

# %%
all_df.isna().sum()
# Out:
# headline_news    0
# dtype: int64

# %%
all_df.to_csv('scraped_news_headline2', index=False)

# %%
main_df.to_csv("C:/Users/HP/Desktop/TerdooNLP/data/scraped_news_headline2.csv",
                 index=False)
